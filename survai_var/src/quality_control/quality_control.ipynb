# %% [markdown]
# # Quality Control App
#
# This app iterates through the existing videos in SurvAI's [var_data](https://app.supabase.com/project/gcqjfsaovvyvuedsquli/editor/19455?sort=index%3Adesc) database and allows you to update the label, time_start, time_end and clarity_level for each.
#
# ### Running the app
#
# 1. `pip install notebook` in your desired environment, if you haven't already.
# 2. You must have a Supabase account and be connected to the 'survai-data' database.
# 3. In a .env file on your local machine, you must have the following info:
#     - SUPABASE_URL="supabase url"
#     - SUPABASE_KEY="supabase key"
#     - EMAIL="email for supabase account"
#     - PASSWORD="password for supabase account"
# 4. In a terminal, cd to the appropriate directory and enter `jupyter notebook quality_control.ipynb`
# 5. Run the cells in order once jupyter notebook is launched.
#
# ### Features
#
# - The third cell will prompt you for a specific label that you wish to review. This will filter the database and create a list of clips that match the specified label.
#
# - Using 'eq' functions, you can filter through whatever combination of data constraints are desired. In its current form, the list of clips will include videos that have a clarity_level 'equal to' none and a label 'equal to' the label you specify. You can add or take away as many of these constraints as you want. Eq functions can be utilized by adding, deleting or modifying the existing line of code in cell 3 that creates the list of clips. Below are specific examples of how to use the eq functions.
#
#     - examples:
#
#         1. A list of videos that have a 'clarity_level' of 'hard' --> eq('clarity_level', 'hard')
#
#         2. A list of videos that have a 'youtube_id' of 'R8vVsPCwKY4' --> eq('youtube_id', 'R8vVsPCwKY4')
#
#         3. A list of videos that have a 'clarity_level' of 'hard' AND a 'youtube_id' of 'R8vVsPCwKY4' --> eq('clarity_level', 'hard').eq('youtube_id', 'R8vVsPCwKY4')

# %%
from IPython.display import HTML, clear_output, YouTubeVideo, IFrame
import time
import os
from supabase import create_client
import datetime
from datetime import date
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
# Connect to database
url = os.environ.get("SUPABASE_URL")
key = os.environ.get("SUPABASE_KEY")
email = os.environ.get("EMAIL")
password = os.environ.get("PASSWORD")
client = create_client(url, key)
user = client.auth.sign_in(email=email, password=password)

# %%
def convert_time(time):
    '''function to convert total seconds to hours, minutes and seconds'''
    return str(datetime.timedelta(seconds=time))

clarity_list = ['easy', 'medium', 'hard', 'bad']

labels = ['brawling', 'crowd', 'restraining', 'running', 'person_on_ground', 'nothing', 
                'spray', 'striking', 'throwing', 'person_pointing', 'advancing', 'aiming']

label = input('enter the label you want to review: ')

# create list of clips with matching labels where clarity_level is none
clips = list(client.table('var_data').select('clarity_level', 'id', 'time_start', 'time_end', 'label').eq('label', label).eq('clarity_level', 'none').execute())[0][1]
clips
# Out:
# enter the label you want to review: person_on_ground
# [{'clarity_level': 'medium',
#   'id': 'yb6DF7zciSA2',
#   'time_start': 64,
#   'time_end': 68,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA10',
#   'time_start': 205,
#   'time_end': 214,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'dQI5JG4q7vY7',
#   'time_start': 42,
#   'time_end': 45,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'dQI5JG4q7vY9',
#   'time_start': 52,
#   'time_end': 55,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'zwhxo-zzlnQ12',
#   'time_start': 54,
#   'time_end': 57,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'zwhxo-zzlnQ13',
#   'time_start': 58,
#   'time_end': 61,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'zwhxo-zzlnQ15',
#   'time_start': 61,
#   'time_end': 65,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi879',
#   'time_start': 1584,
#   'time_end': 1586,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi880',
#   'time_start': 1587,
#   'time_end': 1591,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi885',
#   'time_start': 1665,
#   'time_end': 1668,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA12',
#   'time_start': 229,
#   'time_end': 234,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'cfgGnPIpFLQ2',
#   'time_start': 24,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA13',
#   'time_start': 240,
#   'time_end': 243,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA16',
#   'time_start': 338,
#   'time_end': 351,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'I5gva0o5GPo2',
#   'time_start': 51,
#   'time_end': 76,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'cfgGnPIpFLQ4',
#   'time_start': 92,
#   'time_end': 107,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA18',
#   'time_start': 362,
#   'time_end': 368,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi8127',
#   'time_start': 2582,
#   'time_end': 2587,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi8132',
#   'time_start': 2651,
#   'time_end': 2654,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi8134',
#   'time_start': 2667,
#   'time_end': 2676,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'RoIUcvfDzi8149',
#   'time_start': 3065,
#   'time_end': 3069,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'RoIUcvfDzi8151',
#   'time_start': 3134,
#   'time_end': 3138,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'NkzNcFHnTOk1',
#   'time_start': 0,
#   'time_end': 9,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'SVBfJBVYK7k3',
#   'time_start': 99,
#   'time_end': 104,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg3',
#   'time_start': 47,
#   'time_end': 54,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg12',
#   'time_start': 404,
#   'time_end': 412,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg13',
#   'time_start': 420,
#   'time_end': 433,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg14',
#   'time_start': 434,
#   'time_end': 438,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'dQgT8pjrxSg15',
#   'time_start': 486,
#   'time_end': 489,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg16',
#   'time_start': 496,
#   'time_end': 508,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg17',
#   'time_start': 526,
#   'time_end': 534,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'dQgT8pjrxSg22',
#   'time_start': 673,
#   'time_end': 677,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '6v1ORP9QbJY1',
#   'time_start': 30,
#   'time_end': 32,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA20',
#   'time_start': 376,
#   'time_end': 388,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'PeISX6mswVE6',
#   'time_start': 100,
#   'time_end': 105,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'kGRquMRcL743',
#   'time_start': 73,
#   'time_end': 84,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'kGRquMRcL744',
#   'time_start': 87,
#   'time_end': 93,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'kGRquMRcL745',
#   'time_start': 153,
#   'time_end': 163,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'kGRquMRcL746',
#   'time_start': 170,
#   'time_end': 180,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'kGRquMRcL749',
#   'time_start': 220,
#   'time_end': 224,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'kGRquMRcL7413',
#   'time_start': 292,
#   'time_end': 302,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'kGRquMRcL7415',
#   'time_start': 313,
#   'time_end': 318,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'kGRquMRcL7423',
#   'time_start': 562,
#   'time_end': 572,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'kGRquMRcL7424',
#   'time_start': 578,
#   'time_end': 592,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'eFdq_nJonqQ8',
#   'time_start': 631,
#   'time_end': 636,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'HN9FfLCu1cI4',
#   'time_start': 93,
#   'time_end': 103,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'RNzUYN3RzzE5',
#   'time_start': 37,
#   'time_end': 43,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'RNzUYN3RzzE6',
#   'time_start': 52,
#   'time_end': 56,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'bD8xRm4FBnE2',
#   'time_start': 161,
#   'time_end': 181,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '_meIihnlH2k19',
#   'time_start': 295,
#   'time_end': 301,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'NSat-nRefXY6',
#   'time_start': 201,
#   'time_end': 204,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'NSat-nRefXY8',
#   'time_start': 222,
#   'time_end': 227,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'NSat-nRefXY10',
#   'time_start': 230,
#   'time_end': 236,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '-uaaOVNBQJI3',
#   'time_start': 2,
#   'time_end': 12,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'hCmLmFxjcSk3',
#   'time_start': 20,
#   'time_end': 25,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '_meIihnlH2k21',
#   'time_start': 302,
#   'time_end': 305,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'UBNRj1eRWLs38',
#   'time_start': 663,
#   'time_end': 669,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ebolOvmrW907',
#   'time_start': 36,
#   'time_end': 39,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ebolOvmrW9018',
#   'time_start': 101,
#   'time_end': 108,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ebolOvmrW9020',
#   'time_start': 114,
#   'time_end': 117,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ebolOvmrW9023',
#   'time_start': 131,
#   'time_end': 134,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ebolOvmrW9024',
#   'time_start': 140,
#   'time_end': 151,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '7JKWRE9yx5M6',
#   'time_start': 26,
#   'time_end': 29,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DSrbkPHC6Fo2',
#   'time_start': 90,
#   'time_end': 95,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ixc5jas6U3Q1',
#   'time_start': 4,
#   'time_end': 30,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ixc5jas6U3Q2',
#   'time_start': 37,
#   'time_end': 55,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'r4WFKmznKNQ7',
#   'time_start': 56,
#   'time_end': 58,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'r4WFKmznKNQ9',
#   'time_start': 67,
#   'time_end': 70,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'r4WFKmznKNQ10',
#   'time_start': 74,
#   'time_end': 78,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'r4WFKmznKNQ15',
#   'time_start': 129,
#   'time_end': 130,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'I5gva0o5GPo7',
#   'time_start': 146,
#   'time_end': 152,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'hCmLmFxjcSk5',
#   'time_start': 27,
#   'time_end': 31,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA23',
#   'time_start': 437,
#   'time_end': 442,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'qnpMkLKsLCA16',
#   'time_start': 60,
#   'time_end': 62,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '8oJMGgaww707',
#   'time_start': 23,
#   'time_end': 25,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '8oJMGgaww708',
#   'time_start': 33,
#   'time_end': 42,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '6v1ORP9QbJY9',
#   'time_start': 130,
#   'time_end': 132,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '6v1ORP9QbJY10',
#   'time_start': 215,
#   'time_end': 218,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'c8j3h7fuYsY13',
#   'time_start': 161,
#   'time_end': 167,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '270F8s5TEKY4',
#   'time_start': 123,
#   'time_end': 125,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'fvBypUzgSLs4',
#   'time_start': 28,
#   'time_end': 30,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'IZvA7elG3lg2',
#   'time_start': 28,
#   'time_end': 32,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'I5FjLdHJ8dQ4',
#   'time_start': 41,
#   'time_end': 51,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'I5FjLdHJ8dQ5',
#   'time_start': 59,
#   'time_end': 63,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'I5FjLdHJ8dQ6',
#   'time_start': 76,
#   'time_end': 91,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'I5FjLdHJ8dQ7',
#   'time_start': 114,
#   'time_end': 124,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'I5gva0o5GPo9',
#   'time_start': 174,
#   'time_end': 178,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'w3gjPubsNtI25',
#   'time_start': 318,
#   'time_end': 323,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI29',
#   'time_start': 404,
#   'time_end': 418,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'w3gjPubsNtI31',
#   'time_start': 404,
#   'time_end': 405,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI38',
#   'time_start': 560,
#   'time_end': 563,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI40',
#   'time_start': 572,
#   'time_end': 577,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'w3gjPubsNtI41',
#   'time_start': 381,
#   'time_end': 383,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'w3gjPubsNtI44',
#   'time_start': 621,
#   'time_end': 623,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'w3gjPubsNtI52',
#   'time_start': 658,
#   'time_end': 661,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI53',
#   'time_start': 665,
#   'time_end': 667,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI54',
#   'time_start': 678,
#   'time_end': 686,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI57',
#   'time_start': 764,
#   'time_end': 767,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI60',
#   'time_start': 780,
#   'time_end': 800,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'w3gjPubsNtI79',
#   'time_start': 940,
#   'time_end': 950,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI83',
#   'time_start': 999,
#   'time_end': 1014,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w3gjPubsNtI86',
#   'time_start': 1049,
#   'time_end': 1051,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'w3gjPubsNtI89',
#   'time_start': 1128,
#   'time_end': 1131,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '_meIihnlH2k24',
#   'time_start': 325,
#   'time_end': 334,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'hCmLmFxjcSk10',
#   'time_start': 205,
#   'time_end': 208,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'w3gjPubsNtI93',
#   'time_start': 1145,
#   'time_end': 1147,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'id5mrdT9ojk12',
#   'time_start': 98,
#   'time_end': 106,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'id5mrdT9ojk14',
#   'time_start': 110,
#   'time_end': 112,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'id5mrdT9ojk16',
#   'time_start': 123,
#   'time_end': 130,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'id5mrdT9ojk17',
#   'time_start': 144,
#   'time_end': 154,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'jx0lv3u4WyY7',
#   'time_start': 75,
#   'time_end': 79,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'jx0lv3u4WyY17',
#   'time_start': 95,
#   'time_end': 103,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'jx0lv3u4WyY18',
#   'time_start': 104,
#   'time_end': 108,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '6v1ORP9QbJY13',
#   'time_start': 221,
#   'time_end': 222,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA27',
#   'time_start': 455,
#   'time_end': 478,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'wL-tPhqz_5I15',
#   'time_start': 103,
#   'time_end': 107,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'wL-tPhqz_5I19',
#   'time_start': 118,
#   'time_end': 124,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'wL-tPhqz_5I50',
#   'time_start': 308,
#   'time_end': 313,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'wL-tPhqz_5I79',
#   'time_start': 569,
#   'time_end': 579,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'GhdIacmdz1w4',
#   'time_start': 185,
#   'time_end': 205,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LF8QElXj6HA28',
#   'time_start': 493,
#   'time_end': 517,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'wL-tPhqz_5I84',
#   'time_start': 605,
#   'time_end': 608,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '_5jlfu8N1E02',
#   'time_start': 16,
#   'time_end': 26,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '_5jlfu8N1E04',
#   'time_start': 31,
#   'time_end': 35,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '_5jlfu8N1E08',
#   'time_start': 51,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '_5jlfu8N1E012',
#   'time_start': 49,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'yfJHv72OqWY2',
#   'time_start': 18,
#   'time_end': 19,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'yfJHv72OqWY25',
#   'time_start': 627,
#   'time_end': 630,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'yfJHv72OqWY30',
#   'time_start': 640,
#   'time_end': 647,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'yfJHv72OqWY31',
#   'time_start': 669,
#   'time_end': 672,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'yfJHv72OqWY35',
#   'time_start': 701,
#   'time_end': 704,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'yfJHv72OqWY47',
#   'time_start': 939,
#   'time_end': 942,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '6v1ORP9QbJY15',
#   'time_start': 263,
#   'time_end': 266,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk2',
#   'time_start': 10,
#   'time_end': 20,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk5',
#   'time_start': 82,
#   'time_end': 84,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk6',
#   'time_start': 95,
#   'time_end': 98,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk8',
#   'time_start': 102,
#   'time_end': 104,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk16',
#   'time_start': 148,
#   'time_end': 150,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk21',
#   'time_start': 182,
#   'time_end': 203,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk33',
#   'time_start': 403,
#   'time_end': 406,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk36',
#   'time_start': 413,
#   'time_end': 421,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk38',
#   'time_start': 427,
#   'time_end': 437,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk40',
#   'time_start': 451,
#   'time_end': 457,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'GhdIacmdz1w6',
#   'time_start': 206,
#   'time_end': 221,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '_meIihnlH2k26',
#   'time_start': 354,
#   'time_end': 357,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'YAZqjIllcaE1',
#   'time_start': 8,
#   'time_end': 10,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk66',
#   'time_start': 868,
#   'time_end': 877,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk69',
#   'time_start': 878,
#   'time_end': 900,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk70',
#   'time_start': 905,
#   'time_end': 915,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'KfBmChuh0nk74',
#   'time_start': 937,
#   'time_end': 941,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH603',
#   'time_start': 100,
#   'time_end': 110,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH604',
#   'time_start': 126,
#   'time_end': 143,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH607',
#   'time_start': 217,
#   'time_end': 234,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH609',
#   'time_start': 237,
#   'time_end': 243,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'w644w66qH6011',
#   'time_start': 270,
#   'time_end': 273,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH6012',
#   'time_start': 291,
#   'time_end': 296,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH6014',
#   'time_start': 379,
#   'time_end': 384,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'w644w66qH6015',
#   'time_start': 398,
#   'time_end': 405,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'w644w66qH6016',
#   'time_start': 420,
#   'time_end': 423,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'eppIM1LWppM17',
#   'time_start': 204,
#   'time_end': 220,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'eppIM1LWppM21',
#   'time_start': 247,
#   'time_end': 258,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'FJ1S2cGcwF07',
#   'time_start': 135,
#   'time_end': 155,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'FJ1S2cGcwF08',
#   'time_start': 161,
#   'time_end': 164,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'FJ1S2cGcwF09',
#   'time_start': 168,
#   'time_end': 180,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'FJ1S2cGcwF010',
#   'time_start': 188,
#   'time_end': 198,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'FJ1S2cGcwF011',
#   'time_start': 253,
#   'time_end': 260,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'FJ1S2cGcwF015',
#   'time_start': 285,
#   'time_end': 289,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'FJ1S2cGcwF018',
#   'time_start': 301,
#   'time_end': 310,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'FJ1S2cGcwF021',
#   'time_start': 317,
#   'time_end': 337,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'FJ1S2cGcwF025',
#   'time_start': 369,
#   'time_end': 385,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'uxSsyu63gM85',
#   'time_start': 4,
#   'time_end': 6,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'uxSsyu63gM810',
#   'time_start': 56,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'uxSsyu63gM813',
#   'time_start': 90,
#   'time_end': 95,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'VYopy8i6MiE2',
#   'time_start': 39,
#   'time_end': 52,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Mq6h_EzhsYM2',
#   'time_start': 14,
#   'time_end': 34,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Mq6h_EzhsYM12',
#   'time_start': 155,
#   'time_end': 164,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Mq6h_EzhsYM19',
#   'time_start': 192,
#   'time_end': 201,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'hCmLmFxjcSk14',
#   'time_start': 378,
#   'time_end': 381,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '_meIihnlH2k28',
#   'time_start': 380,
#   'time_end': 385,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Mq6h_EzhsYM25',
#   'time_start': 220,
#   'time_end': 224,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Mq6h_EzhsYM27',
#   'time_start': 232,
#   'time_end': 241,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Mq6h_EzhsYM28',
#   'time_start': 242,
#   'time_end': 247,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Mq6h_EzhsYM46',
#   'time_start': 592,
#   'time_end': 612,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'VuMRM2QonKc3',
#   'time_start': 18,
#   'time_end': 19,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'VuMRM2QonKc5',
#   'time_start': 107,
#   'time_end': 109,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'VuMRM2QonKc9',
#   'time_start': 201,
#   'time_end': 211,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'VuMRM2QonKc10',
#   'time_start': 225,
#   'time_end': 238,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'VuMRM2QonKc13',
#   'time_start': 245,
#   'time_end': 247,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'VuMRM2QonKc14',
#   'time_start': 253,
#   'time_end': 256,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'VuMRM2QonKc22',
#   'time_start': 379,
#   'time_end': 394,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'VuMRM2QonKc23',
#   'time_start': 398,
#   'time_end': 403,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'VuMRM2QonKc27',
#   'time_start': 425,
#   'time_end': 429,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'VuMRM2QonKc32',
#   'time_start': 562,
#   'time_end': 582,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'VuMRM2QonKc37',
#   'time_start': 722,
#   'time_end': 727,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'VuMRM2QonKc45',
#   'time_start': 1179,
#   'time_end': 1193,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Sb97XCeYfVk5',
#   'time_start': 26,
#   'time_end': 31,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Sb97XCeYfVk6',
#   'time_start': 41,
#   'time_end': 49,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Sb97XCeYfVk8',
#   'time_start': 60,
#   'time_end': 69,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Sb97XCeYfVk10',
#   'time_start': 86,
#   'time_end': 92,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Sb97XCeYfVk19',
#   'time_start': 205,
#   'time_end': 213,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Sb97XCeYfVk28',
#   'time_start': 292,
#   'time_end': 302,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Sb97XCeYfVk37',
#   'time_start': 437,
#   'time_end': 440,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Sb97XCeYfVk40',
#   'time_start': 454,
#   'time_end': 474,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Sb97XCeYfVk50',
#   'time_start': 557,
#   'time_end': 575,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Sb97XCeYfVk52',
#   'time_start': 606,
#   'time_end': 626,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Sb97XCeYfVk57',
#   'time_start': 640,
#   'time_end': 642,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Sb97XCeYfVk63',
#   'time_start': 685,
#   'time_end': 690,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Sb97XCeYfVk65',
#   'time_start': 695,
#   'time_end': 709,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'nMl2df1hk943',
#   'time_start': 6,
#   'time_end': 9,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nMl2df1hk9414',
#   'time_start': 64,
#   'time_end': 67,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nMl2df1hk9419',
#   'time_start': 87,
#   'time_end': 91,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'nMl2df1hk9443',
#   'time_start': 370,
#   'time_end': 379,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'nMl2df1hk9447',
#   'time_start': 438,
#   'time_end': 440,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nMl2df1hk9449',
#   'time_start': 463,
#   'time_end': 483,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nMl2df1hk9453',
#   'time_start': 517,
#   'time_end': 532,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'M5lurZh2uLI4',
#   'time_start': 156,
#   'time_end': 160,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'GhdIacmdz1w10',
#   'time_start': 666,
#   'time_end': 671,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'PHg1nCExBt84',
#   'time_start': 28,
#   'time_end': 37,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'PHg1nCExBt86',
#   'time_start': 89,
#   'time_end': 94,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'PHg1nCExBt87',
#   'time_start': 97,
#   'time_end': 112,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'PHg1nCExBt819',
#   'time_start': 388,
#   'time_end': 392,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'PHg1nCExBt831',
#   'time_start': 618,
#   'time_end': 621,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'PHg1nCExBt833',
#   'time_start': 695,
#   'time_end': 699,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'PHg1nCExBt838',
#   'time_start': 736,
#   'time_end': 739,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '86JoZ9cPdcM7',
#   'time_start': 61,
#   'time_end': 68,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '86JoZ9cPdcM9',
#   'time_start': 99,
#   'time_end': 102,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'lfP_5L8epow7',
#   'time_start': 138,
#   'time_end': 141,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'WpfQnEOlkz03',
#   'time_start': 110,
#   'time_end': 117,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'W29B8lFNVZI13',
#   'time_start': 86,
#   'time_end': 88,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'knZxnTfVlgM1',
#   'time_start': 4,
#   'time_end': 24,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'knZxnTfVlgM6',
#   'time_start': 82,
#   'time_end': 102,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'knZxnTfVlgM7',
#   'time_start': 153,
#   'time_end': 173,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'knZxnTfVlgM8',
#   'time_start': 225,
#   'time_end': 235,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'CDvsNvKOgII3',
#   'time_start': 8,
#   'time_end': 12,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'CDvsNvKOgII5',
#   'time_start': 18,
#   'time_end': 27,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'wsB5yymbKXc10',
#   'time_start': 150,
#   'time_end': 153,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'z_vQbDwHuik52',
#   'time_start': 654,
#   'time_end': 658,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'b9gOjBhk1q01',
#   'time_start': 164,
#   'time_end': 165,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'b9gOjBhk1q04',
#   'time_start': 319,
#   'time_end': 321,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'b9gOjBhk1q05',
#   'time_start': 326,
#   'time_end': 328,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'dqp_jdTLOLE10',
#   'time_start': 139,
#   'time_end': 146,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'Tf67XJFLy6U2',
#   'time_start': 90,
#   'time_end': 98,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'Tf67XJFLy6U4',
#   'time_start': 100,
#   'time_end': 110,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '_meIihnlH2k30',
#   'time_start': 392,
#   'time_end': 398,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'nijNaHkkdnc2',
#   'time_start': 198,
#   'time_end': 203,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'axeLvfI8ZtY1',
#   'time_start': 25,
#   'time_end': 27,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'axeLvfI8ZtY2',
#   'time_start': 37,
#   'time_end': 40,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'axeLvfI8ZtY3',
#   'time_start': 45,
#   'time_end': 54,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'axeLvfI8ZtY4',
#   'time_start': 56,
#   'time_end': 69,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 't2Y2cEFKthM5',
#   'time_start': 98,
#   'time_end': 100,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'apZQ0Bny9rc1',
#   'time_start': 56,
#   'time_end': 66,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'apZQ0Bny9rc4',
#   'time_start': 110,
#   'time_end': 118,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'apZQ0Bny9rc5',
#   'time_start': 120,
#   'time_end': 140,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '8v4NOZV2hOE5',
#   'time_start': 168,
#   'time_end': 185,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'FlNaQThJbQU2',
#   'time_start': 29,
#   'time_end': 39,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'FlNaQThJbQU3',
#   'time_start': 45,
#   'time_end': 62,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'FlNaQThJbQU5',
#   'time_start': 77,
#   'time_end': 83,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'FlNaQThJbQU6',
#   'time_start': 93,
#   'time_end': 102,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'FlNaQThJbQU9',
#   'time_start': 116,
#   'time_end': 120,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'FlNaQThJbQU11',
#   'time_start': 138,
#   'time_end': 150,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'FlNaQThJbQU12',
#   'time_start': 176,
#   'time_end': 180,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '74JP0y6xpM3',
#   'time_start': 133,
#   'time_end': 136,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'FlNaQThJbQU13',
#   'time_start': 198,
#   'time_end': 205,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '9KpB7KeJdV01',
#   'time_start': 22,
#   'time_end': 34,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '9KpB7KeJdV02',
#   'time_start': 38,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '9KpB7KeJdV04',
#   'time_start': 54,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '9KpB7KeJdV05',
#   'time_start': 62,
#   'time_end': 74,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '9KpB7KeJdV08',
#   'time_start': 123,
#   'time_end': 129,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '9KpB7KeJdV013',
#   'time_start': 177,
#   'time_end': 182,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '9KpB7KeJdV014',
#   'time_start': 184,
#   'time_end': 188,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '9KpB7KeJdV015',
#   'time_start': 192,
#   'time_end': 196,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '9KpB7KeJdV018',
#   'time_start': 205,
#   'time_end': 208,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '9KpB7KeJdV020',
#   'time_start': 272,
#   'time_end': 277,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '9KpB7KeJdV022',
#   'time_start': 333,
#   'time_end': 336,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '9KpB7KeJdV025',
#   'time_start': 380,
#   'time_end': 382,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '9KpB7KeJdV026',
#   'time_start': 385,
#   'time_end': 387,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'BKGZnB41_e42',
#   'time_start': 93,
#   'time_end': 109,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'BKGZnB41_e43',
#   'time_start': 118,
#   'time_end': 138,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'BKGZnB41_e44',
#   'time_start': 236,
#   'time_end': 251,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'BKGZnB41_e45',
#   'time_start': 274,
#   'time_end': 294,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ljrSFoRABc84',
#   'time_start': 101,
#   'time_end': 121,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ljrSFoRABc85',
#   'time_start': 313,
#   'time_end': 316,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'R8vVsPCwKY45',
#   'time_start': 264,
#   'time_end': 285,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'Y1Wsh8pLfZ01',
#   'time_start': 136,
#   'time_end': 151,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Y1Wsh8pLfZ04',
#   'time_start': 188,
#   'time_end': 193,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Y1Wsh8pLfZ07',
#   'time_start': 257,
#   'time_end': 267,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'Y86VkjfNopY2',
#   'time_start': 53,
#   'time_end': 56,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '4Hn2FjmhP4Q1',
#   'time_start': 0,
#   'time_end': 20,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '4Hn2FjmhP4Q4',
#   'time_start': 110,
#   'time_end': 130,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '4Hn2FjmhP4Q18',
#   'time_start': 1339,
#   'time_end': 1343,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'W4fwiaplfOA8',
#   'time_start': 62,
#   'time_end': 66,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '5ecoxdNX24g4',
#   'time_start': 129,
#   'time_end': 132,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'zPW9YU9z5gg6',
#   'time_start': 230,
#   'time_end': 233,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '76k8TCBkQ0Q6',
#   'time_start': 33,
#   'time_end': 34,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '76k8TCBkQ0Q9',
#   'time_start': 40,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '0Q2Gc76e4JY7',
#   'time_start': 57,
#   'time_end': 60,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'm_dbBk3k1Vw5',
#   'time_start': 41,
#   'time_end': 43,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'm_dbBk3k1Vw14',
#   'time_start': 97,
#   'time_end': 99,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'YY-virWnjoA7',
#   'time_start': 53,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'YzuyDjLTOIQ7',
#   'time_start': 191,
#   'time_end': 193,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'YzuyDjLTOIQ8',
#   'time_start': 203,
#   'time_end': 211,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'YzuyDjLTOIQ9',
#   'time_start': 219,
#   'time_end': 224,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'YzuyDjLTOIQ11',
#   'time_start': 244,
#   'time_end': 246,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'x3e9-wrSDR421',
#   'time_start': 271,
#   'time_end': 273,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'x3e9-wrSDR424',
#   'time_start': 307,
#   'time_end': 316,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'x3e9-wrSDR426',
#   'time_start': 325,
#   'time_end': 327,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'x3e9-wrSDR429',
#   'time_start': 341,
#   'time_end': 344,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '_Xg9GLr36Ao3',
#   'time_start': 38,
#   'time_end': 53,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'GuqSob_u-kE2',
#   'time_start': 3,
#   'time_end': 7,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'GuqSob_u-kE9',
#   'time_start': 47,
#   'time_end': 50,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '-X3hHZzf6OA12',
#   'time_start': 704,
#   'time_end': 709,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '-X3hHZzf6OA13',
#   'time_start': 710,
#   'time_end': 716,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '-X3hHZzf6OA14',
#   'time_start': 719,
#   'time_end': 724,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '-X3hHZzf6OA15',
#   'time_start': 725,
#   'time_end': 727,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '-X3hHZzf6OA16',
#   'time_start': 781,
#   'time_end': 785,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '-X3hHZzf6OA22',
#   'time_start': 976,
#   'time_end': 979,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '-X3hHZzf6OA23',
#   'time_start': 987,
#   'time_end': 1002,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ZkAE0mIcqFk2',
#   'time_start': 164,
#   'time_end': 194,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ZkAE0mIcqFk3',
#   'time_start': 204,
#   'time_end': 234,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'ZkAE0mIcqFk4',
#   'time_start': 265,
#   'time_end': 295,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'cq7uPGkI9Lo1',
#   'time_start': 8,
#   'time_end': 10,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'GpcoYdldlxQ1',
#   'time_start': 0,
#   'time_end': 18,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'GpcoYdldlxQ2',
#   'time_start': 30,
#   'time_end': 45,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'GpcoYdldlxQ3',
#   'time_start': 47,
#   'time_end': 53,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'GpcoYdldlxQ4',
#   'time_start': 55,
#   'time_end': 63,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'GpcoYdldlxQ5',
#   'time_start': 129,
#   'time_end': 131,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'GpcoYdldlxQ15',
#   'time_start': 316,
#   'time_end': 320,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'GpcoYdldlxQ16',
#   'time_start': 323,
#   'time_end': 330,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'iGoCbebZcag2',
#   'time_start': 39,
#   'time_end': 47,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'iGoCbebZcag6',
#   'time_start': 71,
#   'time_end': 91,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'GzK67z8p-w44',
#   'time_start': 99,
#   'time_end': 107,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'GzK67z8p-w46',
#   'time_start': 119,
#   'time_end': 126,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'lYA-b3YPwAU3',
#   'time_start': 0,
#   'time_end': 3,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'lYA-b3YPwAU4',
#   'time_start': 35,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '5V_im4F20Z05',
#   'time_start': 283,
#   'time_end': 290,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'lYA-b3YPwAU6',
#   'time_start': 45,
#   'time_end': 49,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'lYA-b3YPwAU7',
#   'time_start': 54,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'oxKY96LISk42',
#   'time_start': 75,
#   'time_end': 81,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'oxKY96LISk46',
#   'time_start': 82,
#   'time_end': 85,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'oxKY96LISk48',
#   'time_start': 105,
#   'time_end': 107,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'oxKY96LISk49',
#   'time_start': 111,
#   'time_end': 116,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'oxKY96LISk412',
#   'time_start': 158,
#   'time_end': 162,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LvJT_9-uFG41',
#   'time_start': 5,
#   'time_end': 25,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'LvJT_9-uFG45',
#   'time_start': 93,
#   'time_end': 100,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'LvJT_9-uFG46',
#   'time_start': 108,
#   'time_end': 123,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'LvJT_9-uFG49',
#   'time_start': 151,
#   'time_end': 158,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'kDJdXdrZ8kA2',
#   'time_start': 44,
#   'time_end': 48,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'liblOlXhW_U1',
#   'time_start': 23,
#   'time_end': 31,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'liblOlXhW_U3',
#   'time_start': 35,
#   'time_end': 37,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'liblOlXhW_U5',
#   'time_start': 71,
#   'time_end': 74,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'LAamFbSPlRU4',
#   'time_start': 120,
#   'time_end': 130,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '69aE7uGVbuI5',
#   'time_start': 23,
#   'time_end': 26,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '3J3-TSbV6MQ4',
#   'time_start': 47,
#   'time_end': 53,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '3J3-TSbV6MQ7',
#   'time_start': 96,
#   'time_end': 100,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'VQROk8AaDjU2',
#   'time_start': 32,
#   'time_end': 42,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LuvdhrjQMv06',
#   'time_start': 200,
#   'time_end': 224,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'LuvdhrjQMv011',
#   'time_start': 270,
#   'time_end': 290,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'LuvdhrjQMv016',
#   'time_start': 338,
#   'time_end': 342,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'LuvdhrjQMv018',
#   'time_start': 354,
#   'time_end': 356,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'LuvdhrjQMv021',
#   'time_start': 363,
#   'time_end': 377,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'jEbjwrh_Q7I10',
#   'time_start': 130,
#   'time_end': 133,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'XqRYF283zMs7',
#   'time_start': 67,
#   'time_end': 74,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '2IWeIq52meQ4',
#   'time_start': 35,
#   'time_end': 50,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '6cEiTxS9HlU3',
#   'time_start': 39,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'h8hMBNId97Y2',
#   'time_start': 5,
#   'time_end': 7,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'h8hMBNId97Y3',
#   'time_start': 10,
#   'time_end': 14,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'h8hMBNId97Y4',
#   'time_start': 16,
#   'time_end': 23,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'h8hMBNId97Y6',
#   'time_start': 28,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Lx9LzYosIco5',
#   'time_start': 26,
#   'time_end': 30,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Lx9LzYosIco17',
#   'time_start': 77,
#   'time_end': 78,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '19QCaRYQOXU5',
#   'time_start': 62,
#   'time_end': 67,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '19QCaRYQOXU24',
#   'time_start': 410,
#   'time_end': 422,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'gxQYulrBnFY1',
#   'time_start': 39,
#   'time_end': 40,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'gxQYulrBnFY4',
#   'time_start': 56,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X81',
#   'time_start': 14,
#   'time_end': 16,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X84',
#   'time_start': 19,
#   'time_end': 20,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X88',
#   'time_start': 87,
#   'time_end': 89,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X811',
#   'time_start': 92,
#   'time_end': 95,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'DW5Lanit0X812',
#   'time_start': 101,
#   'time_end': 106,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X814',
#   'time_start': 106,
#   'time_end': 108,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X817',
#   'time_start': 149,
#   'time_end': 151,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X820',
#   'time_start': 155,
#   'time_end': 161,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X821',
#   'time_start': 168,
#   'time_end': 170,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'DW5Lanit0X825',
#   'time_start': 189,
#   'time_end': 191,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '-KU-E3OrTes3',
#   'time_start': 34,
#   'time_end': 44,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'XeY_2GnQ8iQ4',
#   'time_start': 52,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'XeY_2GnQ8iQ7',
#   'time_start': 64,
#   'time_end': 76,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'XeY_2GnQ8iQ9',
#   'time_start': 78,
#   'time_end': 84,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'XeY_2GnQ8iQ17',
#   'time_start': 153,
#   'time_end': 154,
# ...
#   'id': 'YkGmcWGokWw33',
#   'time_start': 546,
#   'time_end': 561,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'j78QDwQJVv83',
#   'time_start': 55,
#   'time_end': 63,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'j78QDwQJVv84',
#   'time_start': 64,
#   'time_end': 67,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'j78QDwQJVv85',
#   'time_start': 72,
#   'time_end': 84,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '47swe9Q6cJ82',
#   'time_start': 40,
#   'time_end': 42,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'iNCsowxZWSI2',
#   'time_start': 47,
#   'time_end': 52,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'iNCsowxZWSI3',
#   'time_start': 52,
#   'time_end': 57,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ogaDPQ8550812',
#   'time_start': 118,
#   'time_end': 126,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi822',
#   'time_start': 809,
#   'time_end': 813,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi824',
#   'time_start': 822,
#   'time_end': 830,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi827',
#   'time_start': 890,
#   'time_end': 893,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi828',
#   'time_start': 902,
#   'time_end': 907,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'RoIUcvfDzi829',
#   'time_start': 912,
#   'time_end': 921,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'bsd6NKaKmLs11',
#   'time_start': 157,
#   'time_end': 159,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'PQQ9xOhuFrk1',
#   'time_start': 266,
#   'time_end': 272,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'PQQ9xOhuFrk3',
#   'time_start': 318,
#   'time_end': 333,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'PQQ9xOhuFrk4',
#   'time_start': 337,
#   'time_end': 340,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'nkIZWelJszA2',
#   'time_start': 21,
#   'time_end': 28,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'nkIZWelJszA4',
#   'time_start': 45,
#   'time_end': 60,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nkIZWelJszA5',
#   'time_start': 62,
#   'time_end': 77,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nkIZWelJszA8',
#   'time_start': 150,
#   'time_end': 152,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'nkIZWelJszA9',
#   'time_start': 155,
#   'time_end': 159,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'nkIZWelJszA11',
#   'time_start': 183,
#   'time_end': 194,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '6wk1DAuncN41',
#   'time_start': 20,
#   'time_end': 35,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '6wk1DAuncN43',
#   'time_start': 87,
#   'time_end': 104,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '6wk1DAuncN44',
#   'time_start': 203,
#   'time_end': 209,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'NpE6Y8sFQMI7',
#   'time_start': 88,
#   'time_end': 91,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'VLULh9xg3Vw2',
#   'time_start': 79,
#   'time_end': 83,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'VLULh9xg3Vw3',
#   'time_start': 91,
#   'time_end': 101,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'XEoGl68PbI45',
#   'time_start': 48,
#   'time_end': 52,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '03K5RH89qkU1',
#   'time_start': 0,
#   'time_end': 3,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '03K5RH89qkU2',
#   'time_start': 4,
#   'time_end': 7,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '03K5RH89qkU3',
#   'time_start': 8,
#   'time_end': 11,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '03K5RH89qkU4',
#   'time_start': 45,
#   'time_end': 47,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '03K5RH89qkU5',
#   'time_start': 57,
#   'time_end': 59,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'r5LDhAW0W0k3',
#   'time_start': 13,
#   'time_end': 28,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'r5LDhAW0W0k6',
#   'time_start': 35,
#   'time_end': 40,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'BTh1h6JU-ek3',
#   'time_start': 27,
#   'time_end': 30,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'cfgGnPIpFLQ22',
#   'time_start': 607,
#   'time_end': 619,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'n_EREs1118U4',
#   'time_start': 87,
#   'time_end': 104,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'BTh1h6JU-ek12',
#   'time_start': 97,
#   'time_end': 100,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'wfmcXx1FWWg3',
#   'time_start': 27,
#   'time_end': 32,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'EeXRYn8Iyio9',
#   'time_start': 181,
#   'time_end': 183,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'EeXRYn8Iyio16',
#   'time_start': 261,
#   'time_end': 264,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'MIqzpAsqlCc2',
#   'time_start': 6,
#   'time_end': 14,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'MIqzpAsqlCc5',
#   'time_start': 20,
#   'time_end': 24,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'MIqzpAsqlCc7',
#   'time_start': 60,
#   'time_end': 63,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'HNBDsxmD2yE8',
#   'time_start': 70,
#   'time_end': 75,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'HNBDsxmD2yE10',
#   'time_start': 79,
#   'time_end': 83,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'HNBDsxmD2yE12',
#   'time_start': 88,
#   'time_end': 91,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'uyXNFML86U88',
#   'time_start': 104,
#   'time_end': 106,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '1KtJwup_tK43',
#   'time_start': 15,
#   'time_end': 19,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '1KtJwup_tK48',
#   'time_start': 50,
#   'time_end': 54,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '1KtJwup_tK426',
#   'time_start': 225,
#   'time_end': 231,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '7vtTtKbuFzM10',
#   'time_start': 158,
#   'time_end': 165,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'QPyc5QP9FYM8',
#   'time_start': 232,
#   'time_end': 236,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'QPyc5QP9FYM9',
#   'time_start': 403,
#   'time_end': 406,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '8wNy8cTMkzw5',
#   'time_start': 136,
#   'time_end': 140,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '8wNy8cTMkzw7',
#   'time_start': 267,
#   'time_end': 272,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '8wNy8cTMkzw8',
#   'time_start': 276,
#   'time_end': 281,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'cJy9yMtNGjA10',
#   'time_start': 270,
#   'time_end': 276,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'mSRTDpcyAec29',
#   'time_start': 1861,
#   'time_end': 1870,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'mSRTDpcyAec30',
#   'time_start': 1883,
#   'time_end': 1885,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'mSRTDpcyAec31',
#   'time_start': 1915,
#   'time_end': 1924,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Bu41uRLnxZQ3',
#   'time_start': 18,
#   'time_end': 26,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Bu41uRLnxZQ5',
#   'time_start': 27,
#   'time_end': 30,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'Bu41uRLnxZQ7',
#   'time_start': 31,
#   'time_end': 34,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '_ONict5F3w42',
#   'time_start': 45,
#   'time_end': 60,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '_ONict5F3w44',
#   'time_start': 75,
#   'time_end': 85,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'vOKhqabg-Ys2',
#   'time_start': 4,
#   'time_end': 22,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '5FSX4Qi2Z-k3',
#   'time_start': 118,
#   'time_end': 127,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '5FSX4Qi2Z-k4',
#   'time_start': 129,
#   'time_end': 136,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '5FSX4Qi2Z-k5',
#   'time_start': 137,
#   'time_end': 149,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': '5FSX4Qi2Z-k6',
#   'time_start': 150,
#   'time_end': 164,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '3exVVGoiQKU2',
#   'time_start': 61,
#   'time_end': 64,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'usttcZGjWUs8',
#   'time_start': 727,
#   'time_end': 732,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Jw7kinMggEY6',
#   'time_start': 149,
#   'time_end': 152,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Jw7kinMggEY7',
#   'time_start': 156,
#   'time_end': 164,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Jw7kinMggEY9',
#   'time_start': 167,
#   'time_end': 171,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Jw7kinMggEY10',
#   'time_start': 202,
#   'time_end': 207,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Jw7kinMggEY11',
#   'time_start': 265,
#   'time_end': 278,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'Jw7kinMggEY16',
#   'time_start': 867,
#   'time_end': 878,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'Jw7kinMggEY17',
#   'time_start': 880,
#   'time_end': 884,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Jw7kinMggEY18',
#   'time_start': 885,
#   'time_end': 888,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Jw7kinMggEY29',
#   'time_start': 1025,
#   'time_end': 1045,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Jw7kinMggEY30',
#   'time_start': 1046,
#   'time_end': 1053,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Jw7kinMggEY31',
#   'time_start': 1059,
#   'time_end': 1079,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Spy8iDPRMLg18',
#   'time_start': 1041,
#   'time_end': 1056,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'Spy8iDPRMLg20',
#   'time_start': 1103,
#   'time_end': 1107,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ppQLGf56lg46',
#   'time_start': 539,
#   'time_end': 542,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'x90mMi1zYVo14',
#   'time_start': 1000,
#   'time_end': 1006,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'x90mMi1zYVo15',
#   'time_start': 1028,
#   'time_end': 1047,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'x90mMi1zYVo17',
#   'time_start': 1052,
#   'time_end': 1060,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '8hclBctFyjw1',
#   'time_start': 52,
#   'time_end': 56,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': '8hclBctFyjw2',
#   'time_start': 57,
#   'time_end': 64,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '8hclBctFyjw4',
#   'time_start': 82,
#   'time_end': 89,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ANUmH_TBGzs1',
#   'time_start': 1174,
#   'time_end': 1185,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ANUmH_TBGzs4',
#   'time_start': 1206,
#   'time_end': 1218,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ANUmH_TBGzs5',
#   'time_start': 1219,
#   'time_end': 1226,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'tAuomhS_M1o2',
#   'time_start': 50,
#   'time_end': 65,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'tAuomhS_M1o5',
#   'time_start': 190,
#   'time_end': 205,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'wj9g_L-PUZ811',
#   'time_start': 492,
#   'time_end': 507,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'wj9g_L-PUZ815',
#   'time_start': 578,
#   'time_end': 593,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'wj9g_L-PUZ817',
#   'time_start': 644,
#   'time_end': 659,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'wj9g_L-PUZ823',
#   'time_start': 773,
#   'time_end': 784,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': '19QCaRYQOXU12',
#   'time_start': 193,
#   'time_end': 203,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'CUuThq5Nvlk4',
#   'time_start': 104,
#   'time_end': 108,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'bad',
#   'id': 'jKRKbwsnlrw2',
#   'time_start': 3,
#   'time_end': 14,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'n_EREs1118U11',
#   'time_start': 451,
#   'time_end': 462,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'TPTyPxolnkg7',
#   'time_start': 122,
#   'time_end': 126,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'zS2P2ait14g7',
#   'time_start': 425,
#   'time_end': 434,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'zS2P2ait14g11',
#   'time_start': 615,
#   'time_end': 625,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'GSjGIzX6awY1',
#   'time_start': 2,
#   'time_end': 14,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'GSjGIzX6awY3',
#   'time_start': 39,
#   'time_end': 45,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'GSjGIzX6awY6',
#   'time_start': 55,
#   'time_end': 63,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ADTdMeHlZak2',
#   'time_start': 44,
#   'time_end': 49,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'ADTdMeHlZak5',
#   'time_start': 146,
#   'time_end': 151,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'hard',
#   'id': 'ADTdMeHlZak9',
#   'time_start': 238,
#   'time_end': 243,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': 'ADTdMeHlZak13',
#   'time_start': 275,
#   'time_end': 278,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ADTdMeHlZak15',
#   'time_start': 280,
#   'time_end': 283,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'TLAeTiCA3Dg9',
#   'time_start': 191,
#   'time_end': 206,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'medium',
#   'id': '4FzBtc9dhII2',
#   'time_start': 12,
#   'time_end': 18,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp01',
#   'time_start': 63,
#   'time_end': 74,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp02',
#   'time_start': 75,
#   'time_end': 78,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp03',
#   'time_start': 81,
#   'time_end': 91,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp04',
#   'time_start': 114,
#   'time_end': 117,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp05',
#   'time_start': 118,
#   'time_end': 121,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp06',
#   'time_start': 122,
#   'time_end': 126,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp07',
#   'time_start': 126,
#   'time_end': 129,
#   'label': 'person_on_ground'},
#  {'clarity_level': 'easy',
#   'id': 'ht7Ikz7kVp08',
#   'time_start': 130,
#   'time_end': 133,
#   'label': 'person_on_ground'},
#  ...]

# %%
break_out = False
index = 0

while True:

    id = clips[index]['id']
    start = clips[index]['time_start']
    end = clips[index]['time_end']
    clarity = clips[index]['clarity_level']

    adjusting_annot = True
   

    if break_out == True:
        break

    if clarity != 'none':
        untagged = False
    else:
        untagged = True 


    while adjusting_annot == True:

        # play video
        clear_output(wait=True) 
        vid = YouTubeVideo(id[0:11], start=start, end=end, allow_autoplay=True, width=560, height=315)
        display(vid)

        # print data
        print(f'index:{index}/{len(clips)}', ', id:', id,', label:', label, 
                f', timestamp: {convert_time(start)} - {convert_time(end)}', ', clarity level:', clarity)

        data = input('r = restart vid, t = change timestamp, l = change label, cl = change clarity_level, n = next vid, p = previous vid, exit = exit')


        # restart video
        if data == 'r':
            continue
        

        # update start and/or end time
        if data == 't':
            time_stamp = input('enter new timestamp (2:23, 2:34): ')
            
            try:
                # convert time to total seconds
                start = (int(time_stamp.split(',')[0].split(':')[0]) * 60) + int(time_stamp.split(',')[0].split(':')[1])
                end = (int(time_stamp.split(',')[1].split(':')[0]) * 60) + int(time_stamp.split(',')[1].split(':')[1])

                # update timestamp in var_data
                client.table('var_data').update({'time_start': start, 'time_end': end}).eq('id', id).execute()

                # update timestamp in clips
                clips[index]['time_start'] = start
                clips[index]['time_end'] = end

            except:
                print('invalid input, try again')
                time.sleep(3)


        # update label
        if data == 'l':
            label = input('enter label: ')

            if label in labels:
                # update label in var_data
                client.table('var_data').update({'label': label}).eq('id', id).execute()
                clips[index]['label'] = label
            else:
                print('invalid input, try again')
                time.sleep(3)
                continue
            

        # update clarity_level
        if data == 'cl':
            clarity = input('enter clarity_level (easy, medium, hard or bad): ')

            if clarity in clarity_list:
                # update clarity_level in var_data
                client.table('var_data').update({'clarity_level': clarity}).eq('id', id).execute()
                clips[index]['clarity_level'] = clarity
                untagged = False
            else:
                print('invalid input, try again')
                time.sleep(3)
                continue

        
        # go to next video
        if data == 'n':
            if untagged == True:
                print('no clarity_level tag on video')
                time.sleep(3)
                continue
            else:
                # add the date to the 'reviewed' column
                client.table('var_data').update({'reviewed': str(date.today())}).eq('id', id).execute()
                index += 1
                adjusting_annot = False    

        
        # go to previous video
        if data == 'p':
            index -= 1
            adjusting_annot = False
            break

        # exit program
        if data == 'exit':
            break_out = True
            adjusting_annot = False
            break
