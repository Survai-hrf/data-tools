# %%
import time
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
from supabase import create_client
from datetime import date
from google.cloud import storage
from pytube import YouTube
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip

# %%
# Connect to database
url = os.environ.get("SUPABASE_URL")
key = os.environ.get("SUPABASE_KEY")
email = os.environ.get("EMAIL")
password = os.environ.get("PASSWORD")
client = create_client(url, key)
user = client.auth.sign_in(email=email, password=password)

# connect to gcloud bucket
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'survai-data-connect.json'
storage_client = storage.Client()
bucket_name = 'js_test_bucket'
bucket = storage_client.bucket(bucket_name)

# %%
# All possible entries
all_possible_annotations = ['brawling', 'br', 'restraining', 're', 'pepper spray', 'ps', 'striking', 
                            'st', 'advancing', 'ad', 'crowd', 'cr', 'running', 'ru', 'person on ground', 'pg', 
                            'blood', 'bl', 'throwing', 'th', 'aiming', 'am', 'pointing', 'po', 'nothing', 'no']

value_pairs = {'br': 'brawling', 're': 'restraining', 'ps': 'spray', 'st': 'striking', 'ad': 'advancing', 
                'cr': 'crowd', 'ru': 'running', 'pg': 'person on ground', 'bl': 'blood', 
                'th': 'throwing', 'am': 'aiming', 'po': 'person pointing', 'no': 'nothing'} 

clarity_options = ['easy', 'medium', 'hard']

# %%
def upload_to_bucket(blob_name, file_path, bucket_name):
    '''uploads video clip to appropriate folder in gcloud'''
    try:
        bucket = storage_client.get_bucket(bucket_name)
        blob = bucket.blob(blob_name)
        blob.upload_from_filename(file_path)
    except Exception as e:
        print(e)

# %%
var_data = 'var_data'
urls = 'urls'

# %%
user_id = list(client.table('users').select('email', 'id').eq('email', email).execute())[0][1][0]['id']
date_added = str(date.today())


has_dash = False

# begin application that updates database
while True:
   
    vid_url = input("enter full url of youtube video, or enter d to save & exit")
    list_url = vid_url.split('&list')
    newvid_url = str(list_url[0])

    if newvid_url == 'd': break
    if newvid_url == '': continue

    # generate key for dict
    vid_strs = newvid_url.split("=")
    vid_key = vid_strs[-1]
    if len(vid_key) != 11:
        print("url not entered correctly, try again")
        continue

    # check if url is already in table
    existing_urls = list(client.table(urls).select('url').execute())[0][1]
    url_search = next((item for item in existing_urls if item["url"] == newvid_url), None)
    if url_search is not None:
        print('URL ALREADY USED')
        continue

    # update urls table with new url and create url_id
    client.table(urls).insert({'url': newvid_url, 'youtube_id': vid_key}).execute()
    url_id = list(client.table(urls).select('url', 'id').eq('url', newvid_url).execute())[0][1][0]['id']

    time.sleep(1)
    print(f"Current video: {newvid_url}")

    i = 1
    
    # Begin collecting annotations for the video
    while True:
        user_annotation = input("Add annotation (label), or enter 'x' to delete an annot, enter 'd' if done with video")
        
        if newvid_url == '': continue
        if user_annotation == "d": break
        
        #create unique key id
        new_vid_key = vid_key + str(i)
        
        #if label is valid
        if user_annotation in all_possible_annotations:
            print(f'annot_{i}: {user_annotation}')

            clarity_level = input('Input clarity level (easy, medium, hard)')
            print(f'annot_{i} clarity_level: {clarity_level}')

            if clarity_level not in clarity_options:
                print('INCORRECT ENTRY - RETRY')
                continue
            
            user_segment = input("enter segment (ex: 1:12, 1:20)")
            print(f"annot_{i} segment: {user_segment}")

            if user_segment == '': continue

            try:
                #convert time to total seconds
                user_segment = user_segment.replace(",", "")
                time_list = user_segment.split(' ')
                time_list = [item.split(":") for item in time_list]
                time_list[0][0] = float(time_list[0][0]) * 60
                time_list[1][0] = float(time_list[1][0]) * 60
                time_list[0][1] = float(time_list[0][1])
                time_list[1][1] = float(time_list[1][1])
                time_start = time_list[0][0] + float(time_list[0][1])
                time_end = time_list[1][0] + float(time_list[1][1])
                fill_start = str(int(time_start)).zfill(6)
                fill_end = str(int(time_end)).zfill(6)

            except Exception as e:
                print(e)
                print("INCORRECT ENTRY - RETRYING")
                continue

            #convert label abreviations to full word
            if user_annotation in value_pairs.keys():
                user_annotation = value_pairs[user_annotation]
            
            # fill var_data table with new data
            client.table(var_data).insert({'id': new_vid_key, 'label': user_annotation, 
                                            'time_start': time_start, 'time_end': time_end,
                                            'youtube_id': vid_key, 'clarity_level': clarity_level,
                                            'user_id': user_id, 'date_added': date_added, 'url_id': url_id}).execute()

            # download video
            video = YouTube(newvid_url, use_oauth=True, allow_oauth_cache=True) 
            yt_video = video.streams.get_highest_resolution()
            yt_video.download(output_path='', filename=f"{new_vid_key}.mp4")

            if new_vid_key[0] == '-':
                has_dash = True
                os.rename(f'{new_vid_key}.mp4', f'{new_vid_key[1:]}.mp4')
                new_vid_key = new_vid_key[1:]

            # extract subclip
            ffmpeg_extract_subclip(filename=f'{new_vid_key}.mp4', t1=time_start, t2=time_end, 
                                    targetname=f'{new_vid_key}_{fill_start}_{fill_end}.mp4') 
            os.remove(f'{new_vid_key}.mp4')

            if has_dash == True:
                os.rename(f'{new_vid_key}_{fill_start}_{fill_end}.mp4', 
                            f'-{new_vid_key}_{fill_start}_{fill_end}.mp4')
                new_vid_key = '-' + new_vid_key
                has_dash = False
                
            # upload to gcloud
            upload_to_bucket(f'datasets/var/master_videos/{user_annotation}/{new_vid_key}_{fill_start}_{fill_end}.mp4', 
                            f"{new_vid_key}_{fill_start}_{fill_end}.mp4", bucket_name)
            os.remove(f"{new_vid_key}_{fill_start}_{fill_end}.mp4")
            print('successfully uploaded to gcloud')
            i += 1
        
        elif user_annotation == "x":
            annot_to_delete = input("what annot do you want to delete? (ex: annot_1), Or enter x to cancel")

            if annot_to_delete == '': continue
            if annot_to_delete == 'x': continue

            else:
                print(f'{annot_to_delete}: DELETED')
                ind = annot_to_delete[-1:]
                label = list(client.table(var_data).select('label').eq('id', vid_key+ind).execute())[0][1][0]['label']

                # delete clip from gcloud
                blob = bucket.blob(f"datasets/var/master_videos/{label}/{vid_key+ind}_{fill_start}_{fill_end}.mp4")
                blob.delete()
                print('deleted from gcloud successfully')

                # delete row from var_data table
                client.table(var_data).delete().eq('id', vid_key+ind).execute()             
                continue

        else:
            continue
# Out:
# Current video: https://www.youtube.com/watch?v=UkSbwN8SPRI
# annot_1: br
# annot_1 clarity_level: easy
# annot_1 segment: 0:02, 0:03
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# successfully uploaded to gcloud
# annot_2: st
# annot_2 clarity_level: medium
# annot_2 segment: 0:03, 0:04
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# successfully uploaded to gcloud
# annot_3: cr
# annot_3 clarity_level: easy
# annot_3 segment: 0:07, 0:08
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# successfully uploaded to gcloud
# annot_4: pg
# annot_4 clarity_level: easy
# annot_4 segment: 0:09, 0:10
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# successfully uploaded to gcloud
# annot_5: pg
# annot_5 clarity_level: easy
# annot_5 segment: 0:10, 0;11
# could not convert string to float: '0;11'
# INCORRECT ENTRY - RETRYING
# annot_5: pg
# annot_5 clarity_level: easy
# annot_5 segment: 0:10, 0:11
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# successfully uploaded to gcloud
# annot_6: po
# annot_6 clarity_level: easy
# annot_6 segment: 0:14, 0:15
# Moviepy - Running:
# >>> "+ " ".join(cmd)
# Moviepy - Command successful
# successfully uploaded to gcloud

# %%
data = list(client.table(var_data).select('label', 'index').execute())[0][1]
data
# Out:
# [{'label': 'nothing', 'index': 10748},
#  {'label': 'striking', 'index': 10583},
#  {'label': 'striking', 'index': 10568},
#  {'label': 'brawling', 'index': 10387},
#  {'label': 'person_on_ground', 'index': 10749},
#  {'label': 'brawling', 'index': 10584},
#  {'label': 'striking', 'index': 10567},
#  {'label': 'brawling', 'index': 10388},
#  {'label': 'spray', 'index': 10300},
#  {'label': 'person_on_ground', 'index': 3830},
#  {'label': 'running', 'index': 3831},
#  {'label': 'person_on_ground', 'index': 3832},
#  {'label': 'aiming', 'index': 3833},
#  {'label': 'advancing', 'index': 3834},
#  {'label': 'person_pointing', 'index': 3835},
#  {'label': 'advancing', 'index': 3836},
#  {'label': 'aiming', 'index': 3837},
#  {'label': 'aiming', 'index': 3838},
#  {'label': 'advancing', 'index': 3839},
#  {'label': 'aiming', 'index': 3840},
#  {'label': 'aiming', 'index': 3841},
#  {'label': 'aiming', 'index': 3842},
#  {'label': 'aiming', 'index': 3843},
#  {'label': 'running', 'index': 3844},
#  {'label': 'running', 'index': 3845},
#  {'label': 'aiming', 'index': 3846},
#  {'label': 'person_on_ground', 'index': 3847},
#  {'label': 'person_on_ground', 'index': 3848},
#  {'label': 'restraining', 'index': 3849},
#  {'label': 'person_on_ground', 'index': 3850},
#  {'label': 'aiming', 'index': 9906},
#  {'label': 'aiming', 'index': 9907},
#  {'label': 'aiming', 'index': 9908},
#  {'label': 'aiming', 'index': 9909},
#  {'label': 'restraining', 'index': 9910},
#  {'label': 'aiming', 'index': 9911},
#  {'label': 'aiming', 'index': 9912},
#  {'label': 'aiming', 'index': 9913},
#  {'label': 'aiming', 'index': 9914},
#  {'label': 'aiming', 'index': 9915},
#  {'label': 'restraining', 'index': 9916},
#  {'label': 'person_on_ground', 'index': 9917},
#  {'label': 'person_on_ground', 'index': 9918},
#  {'label': 'striking', 'index': 1749},
#  {'label': 'restraining', 'index': 9919},
#  {'label': 'aiming', 'index': 9920},
#  {'label': 'aiming', 'index': 9921},
#  {'label': 'aiming', 'index': 9922},
#  {'label': 'person_on_ground', 'index': 9923},
#  {'label': 'aiming', 'index': 9924},
#  {'label': 'spray', 'index': 10585},
#  {'label': 'brawling', 'index': 10389},
#  {'label': 'brawling', 'index': 10751},
#  {'label': 'brawling', 'index': 10586},
#  {'label': 'person_on_ground', 'index': 10752},
#  {'label': 'throwing', 'index': 10587},
#  {'label': 'crowd', 'index': 4160},
#  {'label': 'throwing', 'index': 10391},
#  {'label': 'striking', 'index': 10571},
#  {'label': 'brawling', 'index': 10303},
#  {'label': 'spray', 'index': 10259},
#  {'label': 'nothing', 'index': 10201},
#  {'label': 'nothing', 'index': 10202},
#  {'label': 'nothing', 'index': 10203},
#  {'label': 'nothing', 'index': 10204},
#  {'label': 'nothing', 'index': 10205},
#  {'label': 'nothing', 'index': 10206},
#  {'label': 'nothing', 'index': 10207},
#  {'label': 'nothing', 'index': 10208},
#  {'label': 'nothing', 'index': 10210},
#  {'label': 'nothing', 'index': 10211},
#  {'label': 'nothing', 'index': 10212},
#  {'label': 'nothing', 'index': 10213},
#  {'label': 'nothing', 'index': 10214},
#  {'label': 'nothing', 'index': 10215},
#  {'label': 'nothing', 'index': 10216},
#  {'label': 'nothing', 'index': 10217},
#  {'label': 'nothing', 'index': 10218},
#  {'label': 'nothing', 'index': 10219},
#  {'label': 'nothing', 'index': 10220},
#  {'label': 'running', 'index': 10588},
#  {'label': 'striking', 'index': 10754},
#  {'label': 'spray', 'index': 10589},
#  {'label': 'striking', 'index': 10755},
#  {'label': 'spray', 'index': 10590},
#  {'label': 'crowd', 'index': 4161},
#  {'label': 'person_on_ground', 'index': 10756},
#  {'label': 'advancing', 'index': 10591},
#  {'label': 'spray', 'index': 1754},
#  {'label': 'person_on_ground', 'index': 10757},
#  {'label': 'advancing', 'index': 10592},
#  {'label': 'striking', 'index': 10758},
#  {'label': 'striking', 'index': 10759},
#  {'label': 'running', 'index': 10593},
#  {'label': 'spray', 'index': 4167},
#  {'label': 'striking', 'index': 10722},
#  {'label': 'spray', 'index': 10594},
#  {'label': 'aiming', 'index': 9925},
#  {'label': 'aiming', 'index': 9926},
#  {'label': 'aiming', 'index': 9927},
#  {'label': 'aiming', 'index': 9928},
#  {'label': 'throwing', 'index': 4876},
#  {'label': 'aiming', 'index': 9929},
#  {'label': 'aiming', 'index': 9930},
#  {'label': 'aiming', 'index': 9931},
#  {'label': 'restraining', 'index': 9932},
#  {'label': 'aiming', 'index': 9933},
#  {'label': 'aiming', 'index': 9934},
#  {'label': 'aiming', 'index': 9935},
#  {'label': 'aiming', 'index': 9936},
#  {'label': 'aiming', 'index': 9937},
#  {'label': 'aiming', 'index': 9938},
#  {'label': 'aiming', 'index': 9939},
#  {'label': 'aiming', 'index': 9940},
#  {'label': 'aiming', 'index': 9941},
#  {'label': 'aiming', 'index': 9942},
#  {'label': 'aiming', 'index': 9943},
#  {'label': 'aiming', 'index': 9944},
#  {'label': 'aiming', 'index': 9945},
#  {'label': 'aiming', 'index': 9946},
#  {'label': 'restraining', 'index': 9947},
#  {'label': 'aiming', 'index': 9948},
#  {'label': 'aiming', 'index': 9949},
#  {'label': 'running', 'index': 9950},
#  {'label': 'aiming', 'index': 9951},
#  {'label': 'running', 'index': 9952},
#  {'label': 'aiming', 'index': 9953},
#  {'label': 'running', 'index': 9954},
#  {'label': 'aiming', 'index': 9955},
#  {'label': 'aiming', 'index': 9956},
#  {'label': 'running', 'index': 9957},
#  {'label': 'aiming', 'index': 9958},
#  {'label': 'running', 'index': 9959},
#  {'label': 'spray', 'index': 10477},
#  {'label': 'aiming', 'index': 9960},
#  {'label': 'aiming', 'index': 9961},
#  {'label': 'aiming', 'index': 9962},
#  {'label': 'aiming', 'index': 9963},
#  {'label': 'aiming', 'index': 9964},
#  {'label': 'person_on_ground', 'index': 9965},
#  {'label': 'aiming', 'index': 9966},
#  {'label': 'aiming', 'index': 9967},
#  {'label': 'aiming', 'index': 9968},
#  {'label': 'advancing', 'index': 9969},
#  {'label': 'person_on_ground', 'index': 9970},
#  {'label': 'aiming', 'index': 9971},
#  {'label': 'person_on_ground', 'index': 9972},
#  {'label': 'brawling', 'index': 10266},
#  {'label': 'aiming', 'index': 9973},
#  {'label': 'running', 'index': 9974},
#  {'label': 'advancing', 'index': 9975},
#  {'label': 'aiming', 'index': 9976},
#  {'label': 'aiming', 'index': 9977},
#  {'label': 'running', 'index': 9978},
#  {'label': 'aiming', 'index': 9979},
#  {'label': 'aiming', 'index': 9980},
#  {'label': 'aiming', 'index': 9981},
#  {'label': 'aiming', 'index': 9982},
#  {'label': 'aiming', 'index': 9983},
#  {'label': 'aiming', 'index': 9984},
#  {'label': 'aiming', 'index': 9985},
#  {'label': 'restraining', 'index': 9986},
#  {'label': 'person_on_ground', 'index': 9987},
#  {'label': 'restraining', 'index': 9988},
#  {'label': 'person_on_ground', 'index': 9989},
#  {'label': 'aiming', 'index': 9990},
#  {'label': 'person_on_ground', 'index': 10760},
#  {'label': 'person_on_ground', 'index': 10257},
#  {'label': 'striking', 'index': 10595},
#  {'label': 'aiming', 'index': 9991},
#  {'label': 'aiming', 'index': 9992},
#  {'label': 'advancing', 'index': 9993},
#  {'label': 'aiming', 'index': 9994},
#  {'label': 'restraining', 'index': 9995},
#  {'label': 'striking', 'index': 10319},
#  {'label': 'aiming', 'index': 9996},
#  {'label': 'aiming', 'index': 9997},
#  {'label': 'aiming', 'index': 9998},
#  {'label': 'advancing', 'index': 9999},
#  {'label': 'aiming', 'index': 10000},
#  {'label': 'aiming', 'index': 10001},
#  {'label': 'restraining', 'index': 10002},
#  {'label': 'aiming', 'index': 10003},
#  {'label': 'aiming', 'index': 10660},
#  {'label': 'crowd', 'index': 4877},
#  {'label': 'aiming', 'index': 10004},
#  {'label': 'restraining', 'index': 10005},
#  {'label': 'restraining', 'index': 10006},
#  {'label': 'aiming', 'index': 10007},
#  {'label': 'restraining', 'index': 10008},
#  {'label': 'aiming', 'index': 10009},
#  {'label': 'restraining', 'index': 10010},
#  {'label': 'restraining', 'index': 10011},
#  {'label': 'restraining', 'index': 10012},
#  {'label': 'restraining', 'index': 10013},
#  {'label': 'restraining', 'index': 10014},
#  {'label': 'restraining', 'index': 10015},
#  {'label': 'striking', 'index': 10016},
#  {'label': 'restraining', 'index': 10017},
#  {'label': 'restraining', 'index': 10018},
#  {'label': 'restraining', 'index': 10019},
#  {'label': 'restraining', 'index': 10020},
#  {'label': 'restraining', 'index': 10021},
#  {'label': 'restraining', 'index': 10022},
#  {'label': 'restraining', 'index': 10023},
#  {'label': 'restraining', 'index': 10024},
#  {'label': 'restraining', 'index': 10025},
#  {'label': 'restraining', 'index': 10026},
#  {'label': 'restraining', 'index': 10027},
#  {'label': 'running', 'index': 10028},
#  {'label': 'running', 'index': 10029},
#  {'label': 'person_on_ground', 'index': 10030},
#  {'label': 'restraining', 'index': 10031},
#  {'label': 'restraining', 'index': 10032},
#  {'label': 'restraining', 'index': 10033},
#  {'label': 'restraining', 'index': 10478},
#  {'label': 'restraining', 'index': 10034},
#  {'label': 'restraining', 'index': 10035},
#  {'label': 'aiming', 'index': 10036},
#  {'label': 'restraining', 'index': 10037},
#  {'label': 'restraining', 'index': 10038},
#  {'label': 'person_on_ground', 'index': 10039},
#  {'label': 'person_on_ground', 'index': 10040},
#  {'label': 'person_on_ground', 'index': 10041},
#  {'label': 'person_on_ground', 'index': 10042},
#  {'label': 'person_on_ground', 'index': 10043},
#  {'label': 'person_on_ground', 'index': 10044},
#  {'label': 'restraining', 'index': 10045},
#  {'label': 'restraining', 'index': 10046},
#  {'label': 'restraining', 'index': 10047},
#  {'label': 'running', 'index': 10048},
#  {'label': 'person_on_ground', 'index': 10049},
#  {'label': 'restraining', 'index': 10050},
#  {'label': 'restraining', 'index': 10051},
#  {'label': 'person_on_ground', 'index': 10723},
#  {'label': 'restraining', 'index': 10724},
#  {'label': 'throwing', 'index': 10596},
#  {'label': 'restraining', 'index': 10052},
#  {'label': 'restraining', 'index': 10053},
#  {'label': 'restraining', 'index': 10054},
#  {'label': 'restraining', 'index': 10055},
#  {'label': 'restraining', 'index': 10056},
#  {'label': 'person_on_ground', 'index': 10057},
#  {'label': 'restraining', 'index': 10058},
#  {'label': 'restraining', 'index': 10059},
#  {'label': 'restraining', 'index': 10060},
#  {'label': 'restraining', 'index': 10061},
#  {'label': 'restraining', 'index': 10063},
#  {'label': 'person_on_ground', 'index': 10064},
#  {'label': 'person_on_ground', 'index': 10065},
#  {'label': 'person_on_ground', 'index': 10066},
#  {'label': 'person_on_ground', 'index': 10067},
#  {'label': 'running', 'index': 10068},
#  {'label': 'aiming', 'index': 10069},
#  {'label': 'person_on_ground', 'index': 10070},
#  {'label': 'aiming', 'index': 10071},
#  {'label': 'restraining', 'index': 10072},
#  {'label': 'running', 'index': 10073},
#  {'label': 'person_on_ground', 'index': 10074},
#  {'label': 'aiming', 'index': 10075},
#  {'label': 'person_on_ground', 'index': 10076},
#  {'label': 'aiming', 'index': 10661},
#  {'label': 'spray', 'index': 4878},
#  {'label': 'restraining', 'index': 10077},
#  {'label': 'running', 'index': 10078},
#  {'label': 'restraining', 'index': 10079},
#  {'label': 'running', 'index': 10080},
#  {'label': 'restraining', 'index': 10081},
#  {'label': 'restraining', 'index': 10082},
#  {'label': 'restraining', 'index': 10083},
#  {'label': 'person_on_ground', 'index': 10084},
#  {'label': 'person_on_ground', 'index': 10085},
#  {'label': 'restraining', 'index': 10086},
#  {'label': 'restraining', 'index': 10087},
#  {'label': 'restraining', 'index': 10088},
#  {'label': 'restraining', 'index': 10089},
#  {'label': 'restraining', 'index': 10090},
#  {'label': 'restraining', 'index': 10091},
#  {'label': 'restraining', 'index': 10092},
#  {'label': 'restraining', 'index': 10093},
#  {'label': 'restraining', 'index': 10094},
#  {'label': 'restraining', 'index': 10095},
#  {'label': 'restraining', 'index': 10096},
#  {'label': 'restraining', 'index': 10097},
#  {'label': 'aiming', 'index': 10098},
#  {'label': 'restraining', 'index': 10099},
#  {'label': 'restraining', 'index': 10100},
#  {'label': 'person_on_ground', 'index': 10101},
#  {'label': 'restraining', 'index': 10102},
#  {'label': 'aiming', 'index': 10103},
#  {'label': 'restraining', 'index': 10104},
#  {'label': 'restraining', 'index': 10105},
#  {'label': 'person_on_ground', 'index': 10106},
#  {'label': 'brawling', 'index': 10479},
#  {'label': 'restraining', 'index': 10107},
#  {'label': 'restraining', 'index': 10108},
#  {'label': 'aiming', 'index': 10109},
#  {'label': 'aiming', 'index': 10110},
#  {'label': 'restraining', 'index': 10111},
#  {'label': 'restraining', 'index': 10112},
#  {'label': 'restraining', 'index': 10113},
#  {'label': 'running', 'index': 10114},
#  {'label': 'restraining', 'index': 10115},
#  {'label': 'running', 'index': 10763},
#  {'label': 'striking', 'index': 10764},
#  {'label': 'restraining', 'index': 10725},
#  {'label': 'spray', 'index': 10597},
#  {'label': 'restraining', 'index': 10116},
#  {'label': 'restraining', 'index': 10117},
#  {'label': 'restraining', 'index': 10118},
#  {'label': 'restraining', 'index': 10119},
#  {'label': 'restraining', 'index': 10120},
#  {'label': 'restraining', 'index': 10121},
#  {'label': 'restraining', 'index': 10122},
#  {'label': 'advancing', 'index': 10267},
#  {'label': 'brawling', 'index': 10258},
#  {'label': 'person_on_ground', 'index': 10123},
#  {'label': 'person_on_ground', 'index': 10124},
#  {'label': 'restraining', 'index': 10125},
#  {'label': 'restraining', 'index': 10126},
#  {'label': 'restraining', 'index': 10127},
#  {'label': 'restraining', 'index': 10128},
#  {'label': 'restraining', 'index': 10129},
#  {'label': 'restraining', 'index': 10130},
#  {'label': 'restraining', 'index': 10131},
#  {'label': 'person_on_ground', 'index': 10132},
#  {'label': 'restraining', 'index': 10133},
#  {'label': 'restraining', 'index': 10134},
#  {'label': 'nothing', 'index': 10135},
#  {'label': 'nothing', 'index': 10136},
#  {'label': 'nothing', 'index': 10137},
#  {'label': 'nothing', 'index': 10138},
#  {'label': 'nothing', 'index': 10139},
#  {'label': 'nothing', 'index': 10140},
#  {'label': 'nothing', 'index': 10141},
#  {'label': 'nothing', 'index': 10142},
#  {'label': 'nothing', 'index': 10143},
#  {'label': 'nothing', 'index': 10144},
#  {'label': 'nothing', 'index': 10145},
#  {'label': 'nothing', 'index': 10146},
#  {'label': 'nothing', 'index': 10147},
#  {'label': 'nothing', 'index': 10148},
#  {'label': 'brawling', 'index': 10662},
#  {'label': 'nothing', 'index': 10149},
#  {'label': 'nothing', 'index': 10150},
#  {'label': 'nothing', 'index': 10151},
#  {'label': 'nothing', 'index': 10152},
#  {'label': 'nothing', 'index': 10153},
#  {'label': 'nothing', 'index': 10154},
#  {'label': 'nothing', 'index': 10155},
#  {'label': 'nothing', 'index': 10156},
#  {'label': 'nothing', 'index': 10157},
#  {'label': 'nothing', 'index': 10158},
#  {'label': 'nothing', 'index': 10159},
#  {'label': 'nothing', 'index': 10160},
#  {'label': 'nothing', 'index': 10161},
#  {'label': 'nothing', 'index': 10162},
#  {'label': 'nothing', 'index': 10163},
#  {'label': 'nothing', 'index': 10164},
#  {'label': 'nothing', 'index': 10165},
#  {'label': 'nothing', 'index': 10166},
#  {'label': 'nothing', 'index': 10167},
#  {'label': 'nothing', 'index': 10168},
#  {'label': 'nothing', 'index': 10169},
#  {'label': 'nothing', 'index': 10170},
#  {'label': 'nothing', 'index': 10171},
#  {'label': 'nothing', 'index': 10172},
#  {'label': 'nothing', 'index': 10173},
#  {'label': 'nothing', 'index': 10174},
#  {'label': 'nothing', 'index': 10175},
#  {'label': 'nothing', 'index': 10176},
#  {'label': 'nothing', 'index': 10177},
#  {'label': 'nothing', 'index': 10178},
#  {'label': 'nothing', 'index': 10179},
#  {'label': 'nothing', 'index': 10180},
#  {'label': 'nothing', 'index': 10765},
#  {'label': 'restraining', 'index': 10726},
#  {'label': 'running', 'index': 10598},
#  {'label': 'crowd', 'index': 4475},
#  {'label': 'striking', 'index': 10582},
#  {'label': 'running', 'index': 4113},
#  {'label': 'crowd', 'index': 4114},
#  {'label': 'restraining', 'index': 4115},
#  {'label': 'crowd', 'index': 4116},
#  {'label': 'crowd', 'index': 4117},
#  {'label': 'throwing', 'index': 4118},
#  {'label': 'throwing', 'index': 4119},
#  {'label': 'nothing', 'index': 10181},
#  {'label': 'blood', 'index': 10480},
#  {'label': 'nothing', 'index': 10182},
#  {'label': 'nothing', 'index': 10183},
#  {'label': 'nothing', 'index': 10184},
#  {'label': 'nothing', 'index': 10185},
#  {'label': 'nothing', 'index': 10186},
#  {'label': 'nothing', 'index': 10187},
#  {'label': 'nothing', 'index': 10188},
#  {'label': 'nothing', 'index': 10189},
#  {'label': 'nothing', 'index': 10190},
#  {'label': 'nothing', 'index': 10191},
#  {'label': 'nothing', 'index': 10192},
#  {'label': 'nothing', 'index': 10193},
#  {'label': 'nothing', 'index': 10194},
#  {'label': 'nothing', 'index': 10195},
#  {'label': 'nothing', 'index': 10196},
#  {'label': 'nothing', 'index': 10197},
#  {'label': 'nothing', 'index': 10198},
#  {'label': 'nothing', 'index': 10199},
#  {'label': 'nothing', 'index': 10200},
#  {'label': 'brawling', 'index': 10268},
#  {'label': 'nothing', 'index': 10228},
#  {'label': 'nothing', 'index': 10229},
#  {'label': 'nothing', 'index': 10230},
#  {'label': 'nothing', 'index': 10231},
#  {'label': 'nothing', 'index': 10232},
#  {'label': 'nothing', 'index': 10233},
#  {'label': 'nothing', 'index': 10234},
#  {'label': 'nothing', 'index': 10235},
#  {'label': 'nothing', 'index': 10236},
#  {'label': 'nothing', 'index': 10237},
#  {'label': 'crowd', 'index': 10238},
#  {'label': 'advancing', 'index': 10239},
#  {'label': 'striking', 'index': 10240},
#  {'label': 'crowd', 'index': 10241},
#  {'label': 'crowd', 'index': 10242},
#  {'label': 'crowd', 'index': 10243},
#  {'label': 'striking', 'index': 10244},
#  {'label': 'striking', 'index': 10245},
#  {'label': 'crowd', 'index': 10246},
#  {'label': 'brawling', 'index': 10247},
#  {'label': 'running', 'index': 10248},
#  {'label': 'running', 'index': 10249},
#  {'label': 'throwing', 'index': 10251},
#  {'label': 'brawling', 'index': 10252},
#  {'label': 'running', 'index': 10254},
#  {'label': 'running', 'index': 4880},
#  {'label': 'aiming', 'index': 10253},
#  {'label': 'throwing', 'index': 10269},
#  {'label': 'spray', 'index': 6},
#  {'label': 'nothing', 'index': 10766},
#  {'label': 'brawling', 'index': 10727},
#  {'label': 'crowd', 'index': 7},
#  {'label': 'crowd', 'index': 8},
#  {'label': 'crowd', 'index': 9},
#  {'label': 'crowd', 'index': 10},
#  {'label': 'crowd', 'index': 11},
#  {'label': 'crowd', 'index': 12},
#  {'label': 'crowd', 'index': 13},
#  {'label': 'crowd', 'index': 14},
#  {'label': 'advancing', 'index': 15},
#  {'label': 'crowd', 'index': 16},
#  {'label': 'striking', 'index': 17},
#  {'label': 'striking', 'index': 18},
#  {'label': 'person_on_ground', 'index': 19},
#  {'label': 'restraining', 'index': 20},
#  {'label': 'person_on_ground', 'index': 21},
#  {'label': 'restraining', 'index': 22},
#  {'label': 'person_on_ground', 'index': 23},
#  {'label': 'restraining', 'index': 24},
#  {'label': 'restraining', 'index': 25},
#  {'label': 'restraining', 'index': 26},
#  {'label': 'running', 'index': 27},
#  {'label': 'crowd', 'index': 28},
#  {'label': 'crowd', 'index': 29},
#  {'label': 'crowd', 'index': 30},
#  {'label': 'crowd', 'index': 31},
#  {'label': 'crowd', 'index': 32},
#  {'label': 'crowd', 'index': 33},
#  {'label': 'crowd', 'index': 34},
#  {'label': 'crowd', 'index': 35},
#  {'label': 'running', 'index': 36},
#  {'label': 'running', 'index': 37},
#  {'label': 'running', 'index': 38},
#  {'label': 'crowd', 'index': 39},
#  {'label': 'brawling', 'index': 40},
#  {'label': 'striking', 'index': 41},
#  {'label': 'brawling', 'index': 42},
#  {'label': 'striking', 'index': 43},
#  {'label': 'crowd', 'index': 44},
#  {'label': 'crowd', 'index': 45},
#  {'label': 'restraining', 'index': 46},
#  {'label': 'person_on_ground', 'index': 47},
#  {'label': 'crowd', 'index': 48},
#  {'label': 'running', 'index': 49},
#  {'label': 'crowd', 'index': 50},
#  {'label': 'crowd', 'index': 51},
#  {'label': 'crowd', 'index': 52},
#  {'label': 'crowd', 'index': 53},
#  {'label': 'crowd', 'index': 54},
#  {'label': 'crowd', 'index': 55},
#  {'label': 'spray', 'index': 56},
#  {'label': 'crowd', 'index': 57},
#  {'label': 'crowd', 'index': 58},
#  {'label': 'running', 'index': 59},
#  {'label': 'running', 'index': 60},
#  {'label': 'crowd', 'index': 61},
#  {'label': 'crowd', 'index': 62},
#  {'label': 'crowd', 'index': 63},
#  {'label': 'crowd', 'index': 64},
#  {'label': 'crowd', 'index': 65},
#  {'label': 'crowd', 'index': 66},
#  {'label': 'crowd', 'index': 67},
#  {'label': 'crowd', 'index': 68},
#  {'label': 'crowd', 'index': 69},
#  {'label': 'running', 'index': 70},
#  {'label': 'running', 'index': 71},
#  {'label': 'running', 'index': 72},
#  {'label': 'crowd', 'index': 73},
#  {'label': 'restraining', 'index': 74},
#  {'label': 'restraining', 'index': 75},
#  {'label': 'restraining', 'index': 76},
#  {'label': 'person_on_ground', 'index': 10481},
#  {'label': 'striking', 'index': 10767},
#  {'label': 'throwing', 'index': 10728},
#  {'label': 'restraining', 'index': 77},
#  {'label': 'crowd', 'index': 78},
#  {'label': 'crowd', 'index': 79},
#  {'label': 'crowd', 'index': 80},
#  {'label': 'striking', 'index': 10663},
#  {'label': 'crowd', 'index': 4881},
#  {'label': 'running', 'index': 81},
#  {'label': 'crowd', 'index': 82},
#  {'label': 'crowd', 'index': 83},
#  {'label': 'crowd', 'index': 84},
#  {'label': 'crowd', 'index': 85},
#  {'label': 'crowd', 'index': 86},
#  {'label': 'crowd', 'index': 87},
#  {'label': 'advancing', 'index': 88},
#  {'label': 'running', 'index': 89},
#  {'label': 'advancing', 'index': 90},
#  {'label': 'crowd', 'index': 91},
#  {'label': 'crowd', 'index': 92},
#  {'label': 'crowd', 'index': 93},
#  {'label': 'running', 'index': 94},
#  {'label': 'crowd', 'index': 95},
#  {'label': 'crowd', 'index': 96},
#  {'label': 'advancing', 'index': 97},
#  {'label': 'advancing', 'index': 98},
#  {'label': 'spray', 'index': 99},
#  {'label': 'crowd', 'index': 100},
#  {'label': 'crowd', 'index': 101},
#  {'label': 'crowd', 'index': 102},
#  {'label': 'person_on_ground', 'index': 103},
#  {'label': 'running', 'index': 104},
#  {'label': 'crowd', 'index': 105},
#  {'label': 'crowd', 'index': 106},
#  {'label': 'crowd', 'index': 107},
#  {'label': 'crowd', 'index': 108},
#  {'label': 'restraining', 'index': 109},
#  {'label': 'restraining', 'index': 110},
#  {'label': 'person_on_ground', 'index': 111},
#  {'label': 'restraining', 'index': 112},
#  {'label': 'crowd', 'index': 113},
#  {'label': 'crowd', 'index': 114},
#  {'label': 'running', 'index': 115},
#  {'label': 'blood', 'index': 10482},
#  {'label': 'running', 'index': 116},
#  {'label': 'running', 'index': 117},
#  {'label': 'running', 'index': 118},
#  {'label': 'running', 'index': 119},
#  {'label': 'running', 'index': 120},
#  {'label': 'restraining', 'index': 121},
#  {'label': 'person_on_ground', 'index': 122},
#  {'label': 'restraining', 'index': 123},
#  {'label': 'person_on_ground', 'index': 124},
#  {'label': 'running', 'index': 125},
#  {'label': 'restraining', 'index': 126},
#  {'label': 'person_on_ground', 'index': 127},
#  {'label': 'person_on_ground', 'index': 128},
#  {'label': 'restraining', 'index': 129},
#  {'label': 'restraining', 'index': 130},
#  {'label': 'crowd', 'index': 131},
#  {'label': 'crowd', 'index': 132},
#  {'label': 'running', 'index': 133},
#  {'label': 'crowd', 'index': 134},
#  {'label': 'running', 'index': 135},
#  {'label': 'person_on_ground', 'index': 136},
#  {'label': 'striking', 'index': 137},
#  {'label': 'crowd', 'index': 138},
#  {'label': 'crowd', 'index': 139},
#  {'label': 'running', 'index': 140},
#  {'label': 'striking', 'index': 141},
#  {'label': 'crowd', 'index': 142},
#  {'label': 'person_on_ground', 'index': 143},
#  {'label': 'restraining', 'index': 144},
#  {'label': 'brawling', 'index': 10729},
#  {'label': 'crowd', 'index': 145},
#  {'label': 'crowd', 'index': 146},
#  {'label': 'crowd', 'index': 147},
#  {'label': 'crowd', 'index': 148},
#  {'label': 'crowd', 'index': 149},
#  {'label': 'crowd', 'index': 150},
#  {'label': 'crowd', 'index': 151},
#  {'label': 'crowd', 'index': 152},
#  {'label': 'crowd', 'index': 153},
#  {'label': 'crowd', 'index': 154},
#  {'label': 'crowd', 'index': 155},
#  {'label': 'person_on_ground', 'index': 156},
#  {'label': 'person_on_ground', 'index': 157},
#  {'label': 'spray', 'index': 10664},
#  {'label': 'running', 'index': 4882},
#  {'label': 'striking', 'index': 158},
#  {'label': 'striking', 'index': 159},
#  {'label': 'crowd', 'index': 160},
#  {'label': 'running', 'index': 161},
#  {'label': 'crowd', 'index': 162},
#  {'label': 'crowd', 'index': 163},
#  {'label': 'crowd', 'index': 164},
#  {'label': 'crowd', 'index': 165},
#  {'label': 'crowd', 'index': 166},
#  {'label': 'crowd', 'index': 167},
#  {'label': 'crowd', 'index': 168},
#  {'label': 'advancing', 'index': 169},
#  {'label': 'running', 'index': 170},
#  {'label': 'brawling', 'index': 171},
#  {'label': 'person_on_ground', 'index': 172},
#  {'label': 'striking', 'index': 173},
#  {'label': 'person_on_ground', 'index': 174},
#  {'label': 'person_on_ground', 'index': 175},
#  {'label': 'running', 'index': 176},
#  {'label': 'advancing', 'index': 177},
#  {'label': 'running', 'index': 178},
#  {'label': 'advancing', 'index': 179},
#  {'label': 'person_on_ground', 'index': 180},
#  {'label': 'crowd', 'index': 181},
#  {'label': 'advancing', 'index': 182},
#  {'label': 'running', 'index': 183},
#  {'label': 'striking', 'index': 184},
#  {'label': 'advancing', 'index': 185},
#  {'label': 'crowd', 'index': 186},
#  {'label': 'striking', 'index': 187},
#  {'label': 'striking', 'index': 188},
#  {'label': 'running', 'index': 189},
#  {'label': 'crowd', 'index': 190},
#  {'label': 'crowd', 'index': 191},
#  {'label': 'crowd', 'index': 192},
#  {'label': 'advancing', 'index': 193},
#  {'label': 'spray', 'index': 194},
#  {'label': 'spray', 'index': 195},
#  {'label': 'crowd', 'index': 196},
#  {'label': 'crowd', 'index': 197},
#  {'label': 'crowd', 'index': 198},
#  {'label': 'crowd', 'index': 199},
#  {'label': 'running', 'index': 200},
#  {'label': 'advancing', 'index': 201},
#  {'label': 'crowd', 'index': 202},
#  {'label': 'crowd', 'index': 203},
#  {'label': 'restraining', 'index': 204},
#  {'label': 'restraining', 'index': 205},
#  {'label': 'crowd', 'index': 206},
#  {'label': 'crowd', 'index': 207},
#  {'label': 'crowd', 'index': 208},
#  {'label': 'crowd', 'index': 209},
#  {'label': 'advancing', 'index': 210},
#  {'label': 'restraining', 'index': 211},
#  {'label': 'crowd', 'index': 212},
#  {'label': 'person_on_ground', 'index': 10768},
#  {'label': 'person_on_ground', 'index': 10483},
#  {'label': 'striking', 'index': 10769},
#  {'label': 'restraining', 'index': 10730},
#  {'label': 'advancing', 'index': 213},
#  {'label': 'crowd', 'index': 214},
#  {'label': 'advancing', 'index': 215},
#  {'label': 'crowd', 'index': 216},
#  {'label': 'crowd', 'index': 217},
#  {'label': 'crowd', 'index': 218},
#  {'label': 'running', 'index': 219},
#  {'label': 'running', 'index': 220},
#  {'label': 'crowd', 'index': 221},
#  {'label': 'running', 'index': 222},
#  {'label': 'crowd', 'index': 223},
#  {'label': 'running', 'index': 224},
#  {'label': 'crowd', 'index': 225},
#  {'label': 'running', 'index': 226},
#  {'label': 'person_on_ground', 'index': 227},
#  {'label': 'running', 'index': 228},
#  {'label': 'running', 'index': 229},
#  {'label': 'running', 'index': 230},
#  {'label': 'crowd', 'index': 231},
#  {'label': 'crowd', 'index': 232},
#  {'label': 'running', 'index': 233},
#  {'label': 'running', 'index': 234},
#  {'label': 'running', 'index': 235},
#  {'label': 'throwing', 'index': 4884},
#  {'label': 'running', 'index': 236},
#  {'label': 'crowd', 'index': 237},
#  {'label': 'running', 'index': 238},
#  {'label': 'crowd', 'index': 239},
#  {'label': 'crowd', 'index': 240},
#  {'label': 'crowd', 'index': 241},
#  {'label': 'crowd', 'index': 242},
#  {'label': 'crowd', 'index': 243},
#  {'label': 'crowd', 'index': 244},
#  {'label': 'crowd', 'index': 245},
#  {'label': 'crowd', 'index': 246},
#  {'label': 'crowd', 'index': 247},
#  {'label': 'crowd', 'index': 248},
#  {'label': 'crowd', 'index': 249},
#  {'label': 'crowd', 'index': 250},
#  {'label': 'crowd', 'index': 251},
#  {'label': 'crowd', 'index': 252},
#  {'label': 'crowd', 'index': 253},
#  {'label': 'striking', 'index': 254},
#  {'label': 'crowd', 'index': 255},
#  {'label': 'crowd', 'index': 256},
#  {'label': 'crowd', 'index': 257},
#  {'label': 'crowd', 'index': 258},
#  {'label': 'crowd', 'index': 259},
#  {'label': 'crowd', 'index': 260},
#  {'label': 'crowd', 'index': 261},
#  {'label': 'crowd', 'index': 262},
#  {'label': 'crowd', 'index': 263},
#  {'label': 'crowd', 'index': 264},
#  {'label': 'crowd', 'index': 265},
#  {'label': 'crowd', 'index': 266},
#  {'label': 'crowd', 'index': 267},
#  {'label': 'crowd', 'index': 268},
#  {'label': 'crowd', 'index': 269},
#  {'label': 'crowd', 'index': 270},
#  {'label': 'crowd', 'index': 271},
#  {'label': 'running', 'index': 272},
#  {'label': 'brawling', 'index': 10484},
#  {'label': 'running', 'index': 273},
#  {'label': 'crowd', 'index': 274},
#  {'label': 'running', 'index': 275},
#  {'label': 'crowd', 'index': 276},
#  {'label': 'running', 'index': 277},
#  {'label': 'crowd', 'index': 278},
#  {'label': 'advancing', 'index': 279},
#  {'label': 'crowd', 'index': 280},
#  {'label': 'advancing', 'index': 281},
#  {'label': 'blood', 'index': 282},
#  {'label': 'striking', 'index': 10770},
#  {'label': 'crowd', 'index': 283},
#  {'label': 'crowd', 'index': 284},
#  {'label': 'restraining', 'index': 285},
#  {'label': 'crowd', 'index': 286},
#  {'label': 'crowd', 'index': 287},
#  {'label': 'crowd', 'index': 288},
#  {'label': 'crowd', 'index': 289},
#  {'label': 'crowd', 'index': 290},
#  {'label': 'crowd', 'index': 291},
#  {'label': 'advancing', 'index': 292},
#  {'label': 'crowd', 'index': 293},
#  {'label': 'advancing', 'index': 294},
#  {'label': 'restraining', 'index': 295},
#  {'label': 'crowd', 'index': 296},
#  {'label': 'crowd', 'index': 297},
#  {'label': 'crowd', 'index': 298},
#  {'label': 'advancing', 'index': 299},
#  {'label': 'restraining', 'index': 300},
#  {'label': 'crowd', 'index': 301},
#  {'label': 'crowd', 'index': 302},
#  {'label': 'advancing', 'index': 303},
#  {'label': 'running', 'index': 304},
#  {'label': 'brawling', 'index': 305},
#  {'label': 'striking', 'index': 306},
#  {'label': 'striking', 'index': 307},
#  {'label': 'person_on_ground', 'index': 308},
#  {'label': 'person_on_ground', 'index': 309},
#  {'label': 'crowd', 'index': 310},
#  {'label': 'advancing', 'index': 311},
#  {'label': 'striking', 'index': 10665},
#  {'label': 'throwing', 'index': 4885},
#  {'label': 'striking', 'index': 312},
#  {'label': 'crowd', 'index': 313},
#  {'label': 'crowd', 'index': 314},
#  {'label': 'running', 'index': 315},
#  {'label': 'crowd', 'index': 316},
#  {'label': 'crowd', 'index': 317},
#  {'label': 'running', 'index': 318},
#  {'label': 'crowd', 'index': 319},
#  {'label': 'running', 'index': 320},
#  {'label': 'striking', 'index': 321},
#  {'label': 'crowd', 'index': 322},
#  {'label': 'crowd', 'index': 323},
#  {'label': 'crowd', 'index': 324},
#  {'label': 'running', 'index': 325},
#  {'label': 'running', 'index': 326},
#  {'label': 'crowd', 'index': 327},
#  {'label': 'crowd', 'index': 328},
#  {'label': 'running', 'index': 329},
#  {'label': 'spray', 'index': 330},
#  {'label': 'running', 'index': 331},
#  {'label': 'striking', 'index': 332},
#  {'label': 'running', 'index': 333},
#  {'label': 'crowd', 'index': 334},
#  {'label': 'crowd', 'index': 335},
#  {'label': 'crowd', 'index': 336},
#  {'label': 'advancing', 'index': 337},
#  {'label': 'running', 'index': 338},
#  {'label': 'aiming', 'index': 339},
#  {'label': 'advancing', 'index': 340},
#  {'label': 'aiming', 'index': 341},
#  {'label': 'blood', 'index': 342},
#  {'label': 'restraining', 'index': 343},
#  {'label': 'restraining', 'index': 344},
#  {'label': 'restraining', 'index': 345},
#  {'label': 'restraining', 'index': 346},
#  {'label': 'throwing', 'index': 347},
#  {'label': 'running', 'index': 348},
#  {'label': 'striking', 'index': 349},
#  {'label': 'blood', 'index': 350},
#  {'label': 'blood', 'index': 351},
#  {'label': 'person_on_ground', 'index': 10731},
#  {'label': 'striking', 'index': 10771},
#  {'label': 'person_on_ground', 'index': 10732},
#  {'label': 'advancing', 'index': 4474},
#  {'label': 'brawling', 'index': 10485},
#  {'label': 'crowd', 'index': 352},
#  {'label': 'crowd', 'index': 353},
#  {'label': 'throwing', 'index': 354},
#  {'label': 'running', 'index': 355},
#  {'label': 'throwing', 'index': 356},
#  {'label': 'blood', 'index': 357},
#  {'label': 'crowd', 'index': 358},
#  {'label': 'running', 'index': 359},
#  {'label': 'crowd', 'index': 360},
#  {'label': 'crowd', 'index': 361},
#  {'label': 'running', 'index': 362},
#  {'label': 'running', 'index': 363},
#  {'label': 'running', 'index': 364},
#  {'label': 'crowd', 'index': 365},
#  {'label': 'running', 'index': 366},
#  {'label': 'running', 'index': 367},
#  {'label': 'crowd', 'index': 368},
#  {'label': 'crowd', 'index': 369},
#  {'label': 'running', 'index': 370},
#  {'label': 'throwing', 'index': 371},
#  {'label': 'running', 'index': 372},
#  {'label': 'running', 'index': 373},
#  {'label': 'throwing', 'index': 374},
#  {'label': 'throwing', 'index': 375},
#  {'label': 'crowd', 'index': 376},
#  {'label': 'running', 'index': 377},
#  {'label': 'running', 'index': 378},
#  {'label': 'crowd', 'index': 379},
#  {'label': 'running', 'index': 380},
#  {'label': 'crowd', 'index': 381},
#  {'label': 'crowd', 'index': 382},
#  {'label': 'crowd', 'index': 383},
#  {'label': 'crowd', 'index': 384},
#  {'label': 'crowd', 'index': 385},
#  {'label': 'crowd', 'index': 386},
#  {'label': 'running', 'index': 387},
#  {'label': 'crowd', 'index': 388},
#  {'label': 'crowd', 'index': 389},
#  {'label': 'brawling', 'index': 10666},
#  {'label': 'running', 'index': 4886},
#  {'label': 'crowd', 'index': 390},
#  {'label': 'advancing', 'index': 391},
#  {'label': 'crowd', 'index': 392},
#  {'label': 'crowd', 'index': 393},
#  {'label': 'crowd', 'index': 394},
#  {'label': 'advancing', 'index': 395},
#  {'label': 'crowd', 'index': 396},
#  {'label': 'crowd', 'index': 397},
#  {'label': 'running', 'index': 398},
#  {'label': 'crowd', 'index': 399},
#  {'label': 'advancing', 'index': 400},
#  {'label': 'crowd', 'index': 401},
#  {'label': 'advancing', 'index': 402},
#  {'label': 'spray', 'index': 403},
#  {'label': 'person_on_ground', 'index': 404},
#  {'label': 'restraining', 'index': 405},
#  {'label': 'crowd', 'index': 406},
#  {'label': 'crowd', 'index': 407},
#  {'label': 'crowd', 'index': 408},
#  {'label': 'advancing', 'index': 409},
#  {'label': 'person_on_ground', 'index': 410},
#  {'label': 'striking', 'index': 411},
#  {'label': 'advancing', 'index': 412},
#  {'label': 'advancing', 'index': 413},
#  {'label': 'crowd', 'index': 414},
#  {'label': 'advancing', 'index': 415},
#  {'label': 'advancing', 'index': 416},
#  {'label': 'advancing', 'index': 417},
#  {'label': 'restraining', 'index': 10733},
#  {'label': 'person_on_ground', 'index': 4549},
#  {'label': 'crowd', 'index': 418},
#  {'label': 'crowd', 'index': 419},
#  {'label': 'crowd', 'index': 420},
#  {'label': 'advancing', 'index': 421},
#  {'label': 'crowd', 'index': 422},
#  {'label': 'brawling', 'index': 423},
#  {'label': 'crowd', 'index': 424},
#  {'label': 'striking', 'index': 425},
#  {'label': 'crowd', 'index': 426},
#  {'label': 'crowd', 'index': 427},
#  {'label': 'crowd', 'index': 428},
#  {'label': 'crowd', 'index': 429},
#  {'label': 'crowd', 'index': 430},
#  {'label': 'striking', 'index': 10486},
#  {'label': 'crowd', 'index': 431},
#  {'label': 'person_on_ground', 'index': 432},
#  {'label': 'crowd', 'index': 433},
#  {'label': 'crowd', 'index': 434},
#  {'label': 'crowd', 'index': 435},
#  {'label': 'crowd', 'index': 436},
#  {'label': 'crowd', 'index': 437},
#  {'label': 'crowd', 'index': 438},
#  {'label': 'crowd', 'index': 439},
#  {'label': 'running', 'index': 440},
#  {'label': 'crowd', 'index': 441},
#  {'label': 'striking', 'index': 442},
#  {'label': 'crowd', 'index': 443},
#  {'label': 'crowd', 'index': 444},
#  {'label': 'crowd', 'index': 445},
#  {'label': 'crowd', 'index': 446},
#  {'label': 'crowd', 'index': 447},
#  {'label': 'crowd', 'index': 448},
#  {'label': 'spray', 'index': 449},
#  {'label': 'crowd', 'index': 450},
#  {'label': 'spray', 'index': 451},
#  {'label': 'crowd', 'index': 452},
#  {'label': 'crowd', 'index': 453},
#  {'label': 'crowd', 'index': 454},
#  {'label': 'running', 'index': 455},
#  {'label': 'crowd', 'index': 456},
#  {'label': 'advancing', 'index': 457},
#  {'label': 'brawling', 'index': 458},
#  {'label': 'striking', 'index': 459},
#  {'label': 'striking', 'index': 460},
#  {'label': 'person_on_ground', 'index': 461},
#  {'label': 'person_on_ground', 'index': 462},
#  {'label': 'person_on_ground', 'index': 463},
#  {'label': 'person_on_ground', 'index': 464},
#  {'label': 'striking', 'index': 465},
#  {'label': 'striking', 'index': 466},
#  {'label': 'striking', 'index': 467},
#  {'label': 'advancing', 'index': 4887},
#  {'label': 'brawling', 'index': 468},
#  {'label': 'throwing', 'index': 469},
#  {'label': 'striking', 'index': 470},
#  {'label': 'throwing', 'index': 471},
#  {'label': 'striking', 'index': 472},
#  {'label': 'throwing', 'index': 473},
#  {'label': 'throwing', 'index': 474},
#  {'label': 'throwing', 'index': 475},
#  {'label': 'throwing', 'index': 476},
#  {'label': 'throwing', 'index': 477},
#  {'label': 'striking', 'index': 478},
#  {'label': 'striking', 'index': 479},
#  {'label': 'striking', 'index': 480},
#  {'label': 'striking', 'index': 481},
#  {'label': 'brawling', 'index': 482},
#  {'label': 'striking', 'index': 483},
#  {'label': 'striking', 'index': 484},
#  {'label': 'aiming', 'index': 10773},
#  {'label': 'person_on_ground', 'index': 10772},
#  {'label': 'nothing', 'index': 10774},
#  {'label': 'restraining', 'index': 10734},
#  {'label': 'striking', 'index': 485},
#  {'label': 'striking', 'index': 486},
#  {'label': 'person_on_ground', 'index': 487},
#  {'label': 'striking', 'index': 488},
#  {'label': 'striking', 'index': 489},
#  {'label': 'striking', 'index': 490},
#  {'label': 'person_on_ground', 'index': 491},
#  {'label': 'brawling', 'index': 492},
#  {'label': 'person_on_ground', 'index': 493},
#  {'label': 'striking', 'index': 494},
#  {'label': 'striking', 'index': 495},
#  {'label': 'striking', 'index': 496},
#  {'label': 'striking', 'index': 497},
#  {'label': 'striking', 'index': 498},
#  {'label': 'striking', 'index': 499},
#  {'label': 'person_on_ground', 'index': 500},
#  {'label': 'striking', 'index': 501},
#  {'label': 'person_on_ground', 'index': 502},
#  {'label': 'person_on_ground', 'index': 503},
#  {'label': 'striking', 'index': 504},
#  {'label': 'striking', 'index': 505},
#  {'label': 'person_on_ground', 'index': 506},
#  {'label': 'striking', 'index': 507},
#  {'label': 'striking', 'index': 508},
#  {'label': 'striking', 'index': 10487},
#  {'label': 'striking', 'index': 509},
#  {'label': 'striking', 'index': 510},
#  {'label': 'striking', 'index': 511},
#  {'label': 'striking', 'index': 512},
#  {'label': 'striking', 'index': 513},
#  {'label': 'person_on_ground', 'index': 514},
#  {'label': 'person_on_ground', 'index': 515},
#  {'label': 'person_on_ground', 'index': 516},
#  {'label': 'striking', 'index': 517},
#  {'label': 'striking', 'index': 518},
#  {'label': 'person_on_ground', 'index': 519},
#  {'label': 'striking', 'index': 520},
#  {'label': 'striking', 'index': 521},
#  {'label': 'person_on_ground', 'index': 522},
#  {'label': 'striking', 'index': 523},
#  {'label': 'running', 'index': 524},
#  {'label': 'striking', 'index': 525},
#  {'label': 'striking', 'index': 526},
#  {'label': 'striking', 'index': 527},
#  {'label': 'person_pointing', 'index': 528},
#  {'label': 'striking', 'index': 529},
#  {'label': 'striking', 'index': 530},
#  {'label': 'striking', 'index': 531},
#  {'label': 'striking', 'index': 532},
#  ...]

# %%
for i in data:
    label = i['label']
    index = i['index']
    if ' ' in label:
        new_label = label.replace(' ', '_')
        client.table(var_data).update({'label': new_label}).eq('index', index).execute()
