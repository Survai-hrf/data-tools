# %%
import pandas as pd

# %%
df = pd.read_csv('deliverables/pf_detections.csv')
df.sort_values(['Riot Shield'], ascending=False).head(25)
# Out:
#      Unnamed: 0                    file_name  \
# 425         425          drilling_draft1.mp4
# 248         248              Marching_01.mp4
# 150         150  DrillingInstruction_2_3.mp4
# 426         426      latesT_PAtriotfront.mp4
# 66           66          20211030_200848.mp4
# 65           65          20211030_195421.mp4
# 230         230                 MVI_1060.mp4
# 1             1                      009.mp4
# 316         316                 P1000384.mp4
# 118         118           Cross_Media-13.mp4
# 328         328                 P1000396.mp4
# 35           35      2021-11-21_09.09.17.mp4
# 84           84          20211114_084305.mp4
# 380         380      VID_20211024_105919.mp4
# 242         242                 MVI_1086.mp4
# 236         236                 MVI_1066.mp4
# 344         344                 P1000421.mp4
# 245         245                 MVI_1090.mp4
# 388         388      VID_20211123_101900.mp4
# 5             5      2021-11-20_11.20.38.mp4
# ...
